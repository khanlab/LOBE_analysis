# %% [markdown]
# # SFC, FC & SC - LOBE vs HCP #

# %% [markdown]
# ## Importing packages and setting paths ##

# %%
import pandas as pd
import nibabel as nib
from glob import glob
import numpy as np
import statsmodels.api as sp
#imported the full paths since it wasn't working otherwise - not sure why 
from statsmodels.stats.weightstats import ttest_ind
from statsmodels.stats.multitest import fdrcorrection

# %%
#first load up the label dseg table
atlas='schaefer'

df_labels = pd.read_csv('resources/atlas/atlas-{atlas}_dseg.tsv',sep='\t')
df_labels

df_network_names = df_labels.networks.unique()
df_network_names

df_tabular = pd.read_csv('resources/merged_tabular.tsv',sep='\t')
df_tabular
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 #first load up the label dseg table
#       2 atlas='schaefer'
# ----> 4 df_labels = pd.read_csv('../resources/atlas/atlas-{atlas}_dseg.tsv',sep='\t')
#       5 df_labels
#       7 df_network_names = df_labels.networks.unique()
#
# File /localscratch/.cache/pypoetry/virtualenvs/lobe-analysis-fL6lcqD_-py3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /localscratch/.cache/pypoetry/virtualenvs/lobe-analysis-fL6lcqD_-py3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /localscratch/.cache/pypoetry/virtualenvs/lobe-analysis-fL6lcqD_-py3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /localscratch/.cache/pypoetry/virtualenvs/lobe-analysis-fL6lcqD_-py3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /localscratch/.cache/pypoetry/virtualenvs/lobe-analysis-fL6lcqD_-py3.11/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../resources/atlas/atlas-{atlas}_dseg.tsv'

# %%
fc_pattern='results/{dataset}/sub-{subject}/func/sub-{subject}_task-rest_den-32k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-schaefer_bold.pconn.nii'
sc_pattern='results/{dataset}/sub-{subject}/dwi/sub-{subject}_den-32k_atlas-schaefer_struc.pconn.nii'
sfc_pattern='results/{dataset}/sub-{subject}/func/sub-{subject}_task-rest_den-32k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-schaefer_sfc.pscalar.nii'

# %%
sfc_paths={}
sfc_paths['HCP'] = sorted(glob(sfc_pattern.format(dataset='HCP',subject='*')))
sfc_paths['LOBE'] = sorted(glob(sfc_pattern.format(dataset='LOBE',subject='*')))

fc_paths={}
fc_paths['HCP'] = sorted(glob(fc_pattern.format(dataset='HCP',subject='*')))
fc_paths['LOBE'] = sorted(glob(fc_pattern.format(dataset='LOBE',subject='*')))

sc_paths={}
sc_paths['HCP'] = sorted(glob(sc_pattern.format(dataset='HCP',subject='*')))
sc_paths['LOBE'] = sorted(glob(sc_pattern.format(dataset='LOBE',subject='*')))

#print(sfc_paths)
#print(fc_paths)
#print(sc_paths)

# %%
#from snakebids.utils.snakemake_io import glob_wildcards
#subjects = glob_wildcards(sfc_pattern.format(dataset='HCP',subject='{subject}'))

# %%
hacky_hcp_subjects = [ path[12:26] for path in sfc_paths['HCP']]
hacky_hcp_subjects[0]
# Out:
# 'sub-HCD0001305'

# %%
sfc={}
fc={}
sc={}
num_parcels = nib.load(sfc_paths['LOBE'][0]).get_fdata().shape[1]

for dataset in datasets:
    sfc[dataset] = np.concatenate(  [ nib.load(path).get_fdata()  for path in sfc_paths[dataset]] ,axis=0)
    fc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in fc_paths[dataset]] ,axis=0)
    sc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in sc_paths[dataset]] ,axis=0)

# %%
df_tabular
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_tabular
#
# NameError: name 'df_tabular' is not defined

# %%
#this adds RSFC features as new columns to the df_tabular

df_list=[]
for dataset in datasets:
    df_=pd.DataFrame(sfc[dataset],
                 columns=('RSFC_'+df_labels.name))
    
    df_tabular_ = df_tabular.query(f"dataset == '{dataset}'")
    if dataset == 'HCP':
        df_['participant_id'] = hacky_hcp_subjects
    else:
        df_['participant_id'] = list(df_tabular_['participant_id'])
    
    
    df_merged_ = pd.merge(df_tabular_,df_,how='left',on='participant_id')
    df_list.append(df_merged_)

df_tabular = pd.concat(df_list)

# %%
sfc['HCP'].shape
# Out:
# (341, 300)

# %% [markdown]
# # Parcel-Wise, LOBE vs HCP #

# %% [markdown]
# ## SFC ##

# %%
fc['LOBE'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fc['LOBE'].shape
#
# NameError: name 'fc' is not defined

# %%
x1 = sfc['HCP']
x2 = sfc['LOBE']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x1 = sfc['HCP']
#       2 x2 = sfc['LOBE']
#
# NameError: name 'sfc' is not defined

# %%
x2.shape# Define file paths separately for left and right lobe
fc_paths = {
    'Left_Lobe': sorted([os.path.join(lobe_directory, f"sub-{subject}/func/sub-{subject}_task-rest_den-91k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-brainnetome_bold.pconn.nii")
        for subject in left_sided_subs_lobe]),  
    'Right_Lobe': sorted([os.path.join(lobe_directory, f"sub-{subject}/func/sub-{subject}_task-rest_den-91k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-brainnetome_bold.pconn.nii")
        for subject in right_sided_subs_lobe]),  
}

sc_paths = {
    'Left_Lobe': sorted([os.path.join(lobe_directory, f"sub-{subject}/func/sub-{subject}_task-rest_den-91k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-brainnetome_bold.pconn.nii")
        for subject in left_sided_subs_lobe]),  
    'Right_Lobe': sorted([os.path.join(lobe_directory, f"sub-{subject}/func/sub-{subject}_task-rest_den-91k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-brainnetome_bold.pconn.nii")
        for subject in right_sided_subs_lobe]),  
}

# Load atlas labels
atlas = 'brainnetome'
df_labels = pd.read_csv(f'../resources/atlas/atlas-{atlas}_dseg.tsv', sep='\t')

# Now you can compare Left_Lobe to Right_Lobe
# Out:
# (23, 300)

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
# (300,)

# %%
pvals
# Out:
# array([2.19823553e-01, 3.51062986e-01, 1.27458705e-01, 3.14298849e-01,
#        8.37194778e-01, 9.59317585e-01, 1.44900582e-01, 5.88645247e-01,
#        1.81285733e-01, 8.71245333e-01, 8.46768988e-01, 5.88242812e-02,
#        1.21386051e-01, 9.27871120e-01, 4.46061043e-01, 5.36327231e-01,
#        7.26868159e-02, 2.81507381e-01, 9.15475581e-01, 9.78991575e-01,
#        1.28328289e-01, 6.28069987e-02, 1.27124049e-02, 5.98235067e-06,
#        7.62524512e-01, 6.12949289e-01, 9.42084582e-01, 4.18739773e-01,
#        9.24373902e-01, 8.74420119e-01, 7.46129789e-01, 6.28451809e-01,
#        2.51943482e-01, 9.05347778e-01, 8.52242528e-01, 8.76505596e-01,
#        3.26909733e-01, 5.67266058e-01, 6.67390955e-01, 2.79830324e-01,
#        6.76384236e-01, 9.98892177e-01, 5.31938329e-01, 3.54870452e-01,
#        3.47470540e-01, 3.68240654e-01, 9.58443228e-01, 5.12309304e-01,
#        1.06544358e-01, 1.09262732e-01, 7.52968726e-01, 5.56545608e-01,
#        7.68358659e-01, 9.37737275e-01, 4.27854456e-01, 2.42780546e-01,
#        7.37976748e-01, 1.07711642e-01, 7.74016673e-01, 9.94561180e-02,
#        2.71771911e-01, 6.19096589e-01, 7.82877899e-01, 6.17465769e-01,
#        8.45133280e-01, 4.61642256e-01, 3.94115989e-01, 7.08657447e-01,
#        8.71609200e-01, 4.63391596e-01, 3.23970618e-01, 6.27888936e-01,
#        7.11825476e-01, 9.69405460e-01, 3.52539066e-01, 7.77926940e-01,
#        4.32365934e-01, 3.69885595e-01, 3.97397189e-01, 9.68716771e-01,
#        7.71032585e-01, 3.36460600e-01, 2.42306559e-01, 8.04518859e-01,
#        1.49170045e-01, 2.15913086e-01, 7.65699504e-01, 8.67794576e-01,
#        3.21638486e-01, 9.01476895e-02, 2.31104625e-01, 6.92682550e-03,
#        1.91505718e-02, 1.55330694e-02, 1.59472331e-01, 2.16051593e-02,
#        1.84163530e-01, 1.90134687e-01, 1.65099927e-01, 1.22745104e-01,
#        8.19560176e-01, 4.52885089e-01, 9.10114086e-02, 9.30150809e-01,
#        4.93974874e-01, 8.78540104e-01, 3.26044364e-01, 2.83980611e-01,
#        6.50409119e-01, 3.99123529e-01, 9.87728151e-02, 6.53412998e-01,
#        8.76390814e-01, 1.03963853e-01, 9.15395321e-01, 1.82533293e-02,
#        9.15133259e-01, 4.72295695e-01, 7.75512042e-01, 8.59783993e-01,
#        9.38160073e-01, 7.14757500e-02, 8.35188966e-01, 5.55586374e-01,
#        1.59407603e-01, 2.00863995e-01, 2.51405760e-01, 9.18466888e-02,
#        3.61379893e-01, 5.63918780e-01, 1.92636090e-01, 5.98351460e-01,
#        6.92938511e-01, 5.78435212e-01, 7.93387745e-01, 7.45923414e-01,
#        9.56986979e-01, 1.00851152e-01, 6.39475114e-01, 1.87623692e-01,
#        3.51665027e-01, 2.09659077e-01, 4.73969669e-02, 2.61033996e-01,
#        4.94892942e-01, 2.73891225e-01, 7.47710721e-01, 1.95420461e-01,
#        9.10474549e-01, 1.48607557e-01, 2.46582839e-02, 3.47450083e-03,
#        1.74422929e-01, 1.39472870e-01, 5.54119751e-01, 3.02794758e-01,
#        2.48834541e-01, 2.44978714e-01, 6.74601047e-01, 6.67758866e-01,
#        2.35441067e-03, 5.88168444e-01, 5.03187123e-01, 1.90112492e-01,
#        4.83158919e-01, 6.90208548e-02, 5.92062480e-01, 2.65992066e-01,
#        5.15219462e-01, 3.63309980e-01, 7.76630487e-02, 2.39520403e-01,
#        1.09209772e-03, 4.03893339e-01, 3.55713964e-01, 4.60771268e-01,
#        9.78277210e-01, 3.01159494e-01, 9.81227757e-01, 1.97647964e-01,
#        2.20183107e-01, 5.34853319e-01, 1.15701883e-01, 5.93711554e-01,
#        2.18181869e-01, 6.69750468e-02, 1.18031072e-02, 7.75019640e-01,
#        4.87442042e-01, 2.71628073e-01, 1.95881287e-01, 2.21150402e-03,
#        1.15172694e-01, 6.52065780e-01, 1.53389618e-01, 9.88594207e-01,
#        7.23441591e-01, 4.92343415e-01, 3.72718113e-01, 7.04068536e-02,
#        4.13056250e-01, 2.71828192e-02, 9.80787604e-01, 8.42077862e-01,
#        7.78404520e-01, 9.35757772e-01, 5.52077061e-01, 3.15225303e-02,
#        6.39081951e-01, 5.85810748e-01, 9.98915386e-02, 8.33281383e-01,
#        3.94506435e-01, 7.07451652e-01, 9.19962881e-01, 1.04738800e-02,
#        9.25085469e-03, 2.29624208e-03, 6.26044243e-01, 6.36407645e-01,
#        1.59754441e-01, 6.49856709e-01, 5.50789776e-01, 8.53501174e-01,
#        9.84223837e-01, 6.07582868e-01, 9.00048679e-02, 9.99886443e-01,
#        6.09299374e-01, 9.77484200e-01, 2.63575845e-01, 6.92437084e-01,
#        9.08119442e-01, 9.82149961e-01, 6.70541322e-01, 4.16666505e-01,
#        4.17953544e-03, 4.02729874e-01, 4.10010852e-01, 3.78846850e-02,
#        6.20029735e-01, 1.17826476e-01, 7.42027331e-04, 1.95886609e-01,
#        7.99144001e-01, 5.11058622e-02, 5.54889335e-01, 3.82205446e-01,
#        3.75657940e-01, 4.05347472e-02, 7.59983233e-02, 5.61857913e-01,
#        4.90333706e-01, 6.69408731e-01, 8.33766554e-01, 4.60314461e-01,
#        9.20979564e-01, 5.66451334e-01, 9.76458763e-01, 4.71327316e-01,
#        6.02916335e-01, 4.71512694e-01, 5.83963313e-01, 2.65263965e-01,
#        2.46071713e-01, 1.48208972e-01, 8.50261414e-01, 9.38694538e-01,
#        8.62268051e-01, 9.41651591e-01, 1.11863794e-01, 1.47732810e-01,
#        6.15100766e-01, 4.93772275e-01, 7.50944433e-01, 3.57234667e-01,
#        9.26595450e-01, 1.23747224e-01, 8.89405475e-02, 7.80757567e-01,
#        5.97118793e-01, 6.98375765e-01, 3.29119551e-01, 6.07886981e-01,
#        4.40117099e-01, 9.65720458e-02, 7.93553573e-01, 6.21944822e-01,
#        8.41319138e-01, 4.97629858e-01, 5.54698446e-01, 5.56021696e-01,
#        1.35405544e-02, 3.27622011e-01, 2.93450654e-01, 3.29792430e-01,
#        3.40866735e-01, 5.36259091e-01, 9.01092545e-02, 3.43514868e-01])

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %% [markdown]
# # Functional Connectivity #

# %% [markdown]
# ## Average FC per parcel - group difference ##

# %%
#set diagonal to be nan
x1 = fc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = fc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %%
x1.shape
# Out:
# (341, 300, 300)

# %%
x1 = np.nanmean(x1,axis=2)
x2 = np.nanmean(x2,axis=2)

# %%
x1.shape
# Out:
# (341, 300)

# %%
x2.shape
# Out:
# (23, 300)

# %%
#add FC parcel avgs to tabular df

data_={'HCP':x1,'LOBE':x2}

df_list=[]
for dataset in datasets:

    
    df_=pd.DataFrame(data_[dataset],
                 columns=('RFC_'+df_labels.name))
    
    df_tabular_ = df_tabular.query(f"dataset == '{dataset}'")
    if dataset == 'HCP':
        df_['participant_id'] = hacky_hcp_subjects
    else:
        df_['participant_id'] = list(df_tabular_['participant_id'])
    
    
    df_merged_ = pd.merge(df_tabular_,df_,how='left',on='participant_id')
    df_list.append(df_merged_)

df_tabular = pd.concat(df_list)

# %%
print(df_tabular)
# Out:
#     participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0   sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1   sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2   sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3   sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4   sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..             ...     ...        ...  ..        ...          ...   ...
# 18         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 19         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 20         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 21         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 22         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#    focal_seizure_type  generalized_seizures  dre  ...  \
# 0                 NaN                   NaN  NaN  ...
# 1                 NaN                   NaN  NaN  ...
# 2                 NaN                   NaN  NaN  ...
# 3                 NaN                   NaN  NaN  ...
# 4                 NaN                   NaN  NaN  ...
# ..                ...                   ...  ...  ...
# 18              motor                   1.0  0.0  ...
# 19              motor                   0.0  NaN  ...
# 20          non-motor                   1.0  1.0  ...
# 21              motor                   1.0  0.0  ...
# 22              motor                   0.0  1.0  ...
#
#     RFC_7Networks_RH_Default_PFCdPFCm_7  RFC_7Networks_RH_Default_PFCdPFCm_8  \
# 0                              0.219113                             0.166046
# 1                             -0.006497                            -0.038856
# 2                              0.079107                             0.016036
# 3                              0.037525                             0.055458
# 4                              0.013666                             0.068717
# ..                                  ...                                  ...
# 18                             0.490098                             0.508741
# 19                             0.292389                             0.305278
# 20                             0.059956                             0.045759
# 21                            -0.075954                            -0.007454
# 22                             0.235797                             0.164174
#
#     RFC_7Networks_RH_Default_PFCdPFCm_9  RFC_7Networks_RH_Default_PFCdPFCm_10  \
# 0                              0.271345                              0.057813
# 1                              0.046620                             -0.101678
# 2                              0.135757                              0.055646
# 3                              0.081517                              0.035691
# 4                              0.204693                              0.012360
# ..                                  ...                                   ...
# 18                             0.557849                              0.519448
# 19                             0.248295                              0.260900
# 20                             0.030858                              0.066704
# 21                             0.021570                             -0.019798
# 22                             0.176782                              0.175817
#
#     RFC_7Networks_RH_Default_pCunPCC_1  RFC_7Networks_RH_Default_pCunPCC_2  \
# 0                             0.233292                            0.252445
# 1                             0.136620                            0.031924
# 2                             0.096045                            0.137951
# 3                             0.075848                            0.096614
# 4                             0.110496                            0.139785
# ..                                 ...                                 ...
# 18                            0.358857                            0.318778
# 19                            0.182727                            0.157140
# 20                           -0.002951                           -0.022060
# 21                            0.138879                            0.172486
# 22                            0.207441                            0.061922
#
#     RFC_7Networks_RH_Default_pCunPCC_3  RFC_7Networks_RH_Default_pCunPCC_4  \
# 0                             0.204972                            0.285244
# 1                            -0.144353                           -0.119922
# 2                             0.081384                            0.080138
# 3                             0.064724                            0.072942
# 4                            -0.021499                            0.064540
# ..                                 ...                                 ...
# 18                            0.474202                            0.188232
# 19                            0.178925                            0.180137
# 20                           -0.027799                           -0.022163
# 21                            0.132474                            0.117181
# 22                            0.209734                            0.086079
#
#     RFC_7Networks_RH_Default_pCunPCC_5  RFC_7Networks_RH_Default_pCunPCC_6
# 0                             0.141606                            0.182001
# 1                            -0.144181                            0.114270
# 2                             0.018610                            0.071722
# 3                             0.048285                            0.085768
# 4                             0.011546                            0.116300
# ..                                 ...                                 ...
# 18                            0.399420                            0.299900
# 19                            0.156869                            0.169243
# 20                           -0.020411                           -0.002898
# 21                            0.116527                            0.147815
# 22                            0.168359                            0.127602
#
# [372 rows x 628 columns]

# %% [markdown]
# ### Individual T-test ###

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
# (300,)

# %% [markdown]
# ### FDR Correction ###

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
# show if null is rejected after FDR correction, True = significant
rejected
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %% [markdown]
# # Structural Connectivity #

# %% [markdown]
# ## Average SC per parcel - group difference ##

# %%
#set diagonal to be nan
x1 = sc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = sc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %%
x1.shape
# Out:
# (341, 300, 300)

# %%
x1 = np.nanmean(x1,axis=2)
x1.shape
x2 = np.nanmean(x2,axis=2)
x2.shape
# Out:
# (23, 300)

# %%
x1.shape
# Out:
# (341, 300)

# %%
x2.shape
# Out:
# (23, 300)

# %%
#add SC parcel avgs to tabular df

data_={'HCP':x1,'LOBE':x2}

df_list=[]
for dataset in datasets:

    
    df_=pd.DataFrame(data_[dataset],
                 columns=('RSC_'+df_labels.name))
    
    df_tabular_ = df_tabular.query(f"dataset == '{dataset}'")
    if dataset == 'HCP':
        df_['participant_id'] = hacky_hcp_subjects
    else:
        df_['participant_id'] = list(df_tabular_['participant_id'])
    
    
    df_merged_ = pd.merge(df_tabular_,df_,how='left',on='participant_id')
    df_list.append(df_merged_)

df_tabular = pd.concat(df_list)

# %%
df_tabular
# Out:
#     participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0   sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1   sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2   sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3   sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4   sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..             ...     ...        ...  ..        ...          ...   ...
# 18         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 19         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 20         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 21         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 22         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#    focal_seizure_type  generalized_seizures  dre  ...  \
# 0                 NaN                   NaN  NaN  ...
# 1                 NaN                   NaN  NaN  ...
# 2                 NaN                   NaN  NaN  ...
# 3                 NaN                   NaN  NaN  ...
# 4                 NaN                   NaN  NaN  ...
# ..                ...                   ...  ...  ...
# 18              motor                   1.0  0.0  ...
# 19              motor                   0.0  NaN  ...
# 20          non-motor                   1.0  1.0  ...
# 21              motor                   1.0  0.0  ...
# 22              motor                   0.0  1.0  ...
#
#     RSC_7Networks_RH_Default_PFCdPFCm_7  RSC_7Networks_RH_Default_PFCdPFCm_8  \
# 0                             14.844157                            15.208391
# 1                             14.454994                             8.395796
# 2                             13.889760                            12.957404
# 3                             21.165592                            13.562098
# 4                             22.301299                             8.759729
# ..                                  ...                                  ...
# 18                            19.028710                             8.342776
# 19                            16.960664                            16.462967
# 20                            14.291480                            10.521352
# 21                            15.359479                             9.876812
# 22                            21.896079                            11.804770
#
#     RSC_7Networks_RH_Default_PFCdPFCm_9  RSC_7Networks_RH_Default_PFCdPFCm_10  \
# 0                             20.545357                             20.011699
# 1                             13.738416                             14.700760
# 2                             18.191067                             20.401691
# 3                             17.818852                             22.240259
# 4                             18.507906                             15.216472
# ..                                  ...                                   ...
# 18                            18.587800                             16.902234
# 19                            19.383860                             25.676945
# 20                            19.107467                             18.687367
# 21                            19.154256                             25.053800
# 22                            16.926624                             16.847606
#
#     RSC_7Networks_RH_Default_pCunPCC_1  RSC_7Networks_RH_Default_pCunPCC_2  \
# 0                             9.874583                            7.119848
# 1                             7.839966                            5.910502
# 2                             6.084737                            6.723275
# 3                             5.806375                            5.222681
# 4                             5.089299                            3.803380
# ..                                 ...                                 ...
# 18                            8.433928                            5.127071
# 19                           10.450205                            6.463145
# 20                            6.589493                            5.635943
# 21                            6.786074                            5.924701
# 22                            4.221834                            6.037319
#
#     RSC_7Networks_RH_Default_pCunPCC_3  RSC_7Networks_RH_Default_pCunPCC_4  \
# 0                             8.502915                            8.000757
# 1                             6.833241                            6.978524
# 2                             7.880876                            7.008210
# 3                             6.741655                            6.136430
# 4                             4.383564                            6.403444
# ..                                 ...                                 ...
# 18                            6.260919                            4.993658
# 19                            8.535226                            7.709845
# 20                            8.236162                            7.513440
# 21                            7.349385                            7.168108
# 22                            5.922839                            8.795962
#
#     RSC_7Networks_RH_Default_pCunPCC_5  RSC_7Networks_RH_Default_pCunPCC_6
# 0                             9.652369                            5.166225
# 1                             8.193208                            3.897537
# 2                            10.270747                            3.955877
# 3                             8.931968                            5.828264
# 4                             5.134533                            3.186134
# ..                                 ...                                 ...
# 18                            8.733412                            2.258928
# 19                            8.528428                            3.513172
# 20                            8.032734                            2.817005
# 21                            6.827848                            2.840658
# 22                            6.652696                            5.880900
#
# [372 rows x 928 columns]

# %% [markdown]
# ### Individual T-test ###

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
# (300,)

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %% [markdown]
# # Network-Wise, LOBE vs HCP #

# %%
fc_network_pattern='results/{dataset}/sub-{subject}/func/sub-{subject}_task-rest_den-32k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-schaefer_netbold.pconn.nii'
sc_network_pattern='results/{dataset}/sub-{subject}/dwi/sub-{subject}_den-32k_atlas-schaefer_netstruc.pconn.nii'
sfc_network_pattern='results/{dataset}/sub-{subject}/func/sub-{subject}_task-rest_den-32k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-schaefer_netsfc.pconn.nii'


datasets=['HCP','LOBE']

# %%
sfc_netpaths={}
sfc_netpaths['HCP'] = sorted(glob(sfc_network_pattern.format(dataset='HCP',subject='*')))
sfc_netpaths['LOBE'] = sorted(glob(sfc_network_pattern.format(dataset='LOBE',subject='*')))

fc_netpaths={}
fc_netpaths['HCP'] = sorted(glob(fc_network_pattern.format(dataset='HCP',subject='*')))
fc_netpaths['LOBE'] = sorted(glob(fc_network_pattern.format(dataset='LOBE',subject='*')))

sc_netpaths={}
sc_netpaths['HCP'] = sorted(glob(sc_network_pattern.format(dataset='HCP',subject='*')))
sc_netpaths['LOBE'] = sorted(glob(sc_network_pattern.format(dataset='LOBE',subject='*')))

#print(sfc_netpaths)
#print(fc_netpaths)
#print(sc_netpaths)

# %%
sfc={}
fc={}
sc={}
num_parcels = nib.load(sfc_netpaths['LOBE'][0]).get_fdata().shape[1]

for dataset in datasets:
    sfc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in sfc_netpaths[dataset]] ,axis=0)  
    #for path in sfc_netpaths[dataset]] ,axis=0)
    fc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in fc_netpaths[dataset]] ,axis=0)
    sc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in sc_netpaths[dataset]] ,axis=0)

# %% [markdown]
# ## SFC ##

# %%
sfc['LOBE'].shape
# Out:
# (23, 7, 7)

# %% [markdown]
# ### Average per Network - group difference ###

# %%
#set diagonal to be nan
x1 = sfc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = sfc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %%
x1.shape
# Out:
# (341, 7, 7)

# %%
x1 = np.nanmean(x1,axis=2)
x2 = np.nanmean(x2,axis=2)

# %%
x1.shape
# Out:
# (341, 7)

# %%
x1
# Out:
# array([[ 0.13693915,  0.05003615,  0.08362471, ...,  0.09395217,
#          0.07517542,  0.0838999 ],
#        [ 0.04852998,  0.02486698,  0.10213841, ...,  0.0310175 ,
#          0.07976645,  0.12653574],
#        [ 0.14869973,  0.02676821,  0.1551025 , ...,  0.11501908,
#          0.12678167,  0.12783747],
#        ...,
#        [-0.02605158,  0.01312716,  0.11911449, ...,  0.03174289,
#          0.11662567,  0.08154564],
#        [ 0.04825305,  0.0414488 ,  0.16903612, ...,  0.09852805,
#          0.09137343,  0.14288603],
#        [ 0.10234147,  0.06607296,  0.14907431, ...,  0.08672802,
#          0.08164697,  0.13172544]])

# %%
x2.shape
# Out:
# (23, 7)

# %%
#add SFC network avgs to tabular df

data_={'HCP':x1,'LOBE':x2}

df_list=[]
for dataset in datasets:

    
    df_=pd.DataFrame(data_[dataset],
                 columns=('NSFC_'+df_network_names))
    
    df_tabular_ = df_tabular.query(f"dataset == '{dataset}'")
    if dataset == 'HCP':
        df_['participant_id'] = hacky_hcp_subjects
    else:
        df_['participant_id'] = list(df_tabular_['participant_id'])
    
    
    df_merged_ = pd.merge(df_tabular_,df_,how='left',on='participant_id')
    df_list.append(df_merged_)

df_tabular = pd.concat(df_list)

# %%
print(df_tabular)
# Out:
#     participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0   sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1   sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2   sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3   sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4   sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..             ...     ...        ...  ..        ...          ...   ...
# 18         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 19         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 20         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 21         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 22         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#    focal_seizure_type  generalized_seizures  dre  ...  \
# 0                 NaN                   NaN  NaN  ...
# 1                 NaN                   NaN  NaN  ...
# 2                 NaN                   NaN  NaN  ...
# 3                 NaN                   NaN  NaN  ...
# 4                 NaN                   NaN  NaN  ...
# ..                ...                   ...  ...  ...
# 18              motor                   1.0  0.0  ...
# 19              motor                   0.0  NaN  ...
# 20          non-motor                   1.0  1.0  ...
# 21              motor                   1.0  0.0  ...
# 22              motor                   0.0  1.0  ...
#
#     RSC_7Networks_RH_Default_pCunPCC_4  RSC_7Networks_RH_Default_pCunPCC_5  \
# 0                             8.000757                            9.652369
# 1                             6.978524                            8.193208
# 2                             7.008210                           10.270747
# 3                             6.136430                            8.931968
# 4                             6.403444                            5.134533
# ..                                 ...                                 ...
# 18                            4.993658                            8.733412
# 19                            7.709845                            8.528428
# 20                            7.513440                            8.032734
# 21                            7.168108                            6.827848
# 22                            8.795962                            6.652696
#
#     RSC_7Networks_RH_Default_pCunPCC_6  NSFC_Vis  NSFC_SomMot  NSFC_DorsAttn  \
# 0                             5.166225  0.136939     0.050036       0.083625
# 1                             3.897537  0.048530     0.024867       0.102138
# 2                             3.955877  0.148700     0.026768       0.155102
# 3                             5.828264  0.097500     0.091008       0.207202
# 4                             3.186134  0.084767     0.066438       0.128227
# ..                                 ...       ...          ...            ...
# 18                            2.258928  0.026171     0.062618       0.006634
# 19                            3.513172  0.029753     0.027741       0.050927
# 20                            2.817005  0.039138     0.024291       0.061876
# 21                            2.840658  0.100265     0.011197       0.076058
# 22                            5.880900  0.068454     0.063692       0.074541
#
#     NSFC_SalVentAttn  NSFC_Limbic  NSFC_Cont  NSFC_Default
# 0           0.045719     0.093952   0.075175      0.083900
# 1           0.100452     0.031018   0.079766      0.126536
# 2           0.087117     0.115019   0.126782      0.127837
# 3           0.105028     0.063086   0.146761      0.118340
# 4           0.074112     0.060168   0.075408      0.071475
# ..               ...          ...        ...           ...
# 18          0.108769     0.022609   0.058438      0.058284
# 19          0.068785     0.019213   0.049201      0.078785
# 20          0.039205     0.063671   0.095196      0.091614
# 21          0.071911     0.078378   0.078890      0.054699
# 22          0.087431     0.085212   0.079849      0.084982
#
# [372 rows x 935 columns]

# %% [markdown]
# ### T-test and FDR ###

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
pvals
# Out:
# array([0.2363475 , 0.06810607, 0.15582235, 0.80812923, 0.8984041 ,
#        0.0316388 , 0.97137546])

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False])

# %% [markdown]
# ## Functional Connectivity ##

# %%
#set diagonal to be nan
x1 = fc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = fc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %% [markdown]
# ### Average FC per network - group difference ###

# %%
x1 = np.nanmean(x1,axis=2)
x2 = np.nanmean(x2,axis=2)

# %%
x2.shape
# Out:
# (23, 7)

# %%
#add FC network avgs to tabular df

data_={'HCP':x1,'LOBE':x2}

df_list=[]
for dataset in datasets:

    
    df_=pd.DataFrame(data_[dataset],
                 columns=('NFC_'+df_network_names))
    
    df_tabular_ = df_tabular.query(f"dataset == '{dataset}'")
    if dataset == 'HCP':
        df_['participant_id'] = hacky_hcp_subjects
    else:
        df_['participant_id'] = list(df_tabular_['participant_id'])
    
    
    df_merged_ = pd.merge(df_tabular_,df_,how='left',on='participant_id')
    df_list.append(df_merged_)

df_tabular = pd.concat(df_list)

# %%
print(df_tabular)
# Out:
#     participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0   sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1   sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2   sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3   sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4   sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..             ...     ...        ...  ..        ...          ...   ...
# 18         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 19         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 20         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 21         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 22         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#    focal_seizure_type  generalized_seizures  dre  ...  NSFC_Limbic  NSFC_Cont  \
# 0                 NaN                   NaN  NaN  ...     0.093952   0.075175
# 1                 NaN                   NaN  NaN  ...     0.031018   0.079766
# 2                 NaN                   NaN  NaN  ...     0.115019   0.126782
# 3                 NaN                   NaN  NaN  ...     0.063086   0.146761
# 4                 NaN                   NaN  NaN  ...     0.060168   0.075408
# ..                ...                   ...  ...  ...          ...        ...
# 18              motor                   1.0  0.0  ...     0.022609   0.058438
# 19              motor                   0.0  NaN  ...     0.019213   0.049201
# 20          non-motor                   1.0  1.0  ...     0.063671   0.095196
# 21              motor                   1.0  0.0  ...     0.078378   0.078890
# 22              motor                   0.0  1.0  ...     0.085212   0.079849
#
#     NSFC_Default   NFC_Vis  NFC_SomMot  NFC_DorsAttn  NFC_SalVentAttn  \
# 0       0.083900  0.124718    0.177483      0.297615         0.252617
# 1       0.126536  0.091186    0.150995      0.136922         0.172307
# 2       0.127837  0.106908    0.166418      0.136965         0.072332
# 3       0.118340  0.052869    0.038728      0.044547         0.022011
# 4       0.071475  0.167211    0.092118      0.150585         0.146504
# ..           ...       ...         ...           ...              ...
# 18      0.058284  0.386741    0.429620      0.366554         0.433784
# 19      0.078785  0.169395    0.218928      0.155071         0.246947
# 20      0.091614 -0.005393   -0.006498     -0.005387         0.000966
# 21      0.054699  0.034325    0.036441      0.075940        -0.002596
# 22      0.084982  0.158922    0.150807      0.111286         0.131693
#
#     NFC_Limbic  NFC_Cont  NFC_Default
# 0     0.200019  0.257366     0.135539
# 1    -0.000347  0.147511     0.039930
# 2     0.093052  0.082952     0.052142
# 3    -0.001980 -0.008243     0.010302
# 4     0.091706  0.153798     0.082643
# ..         ...       ...          ...
# 18    0.467955  0.392260     0.372756
# 19    0.228163  0.205326     0.162994
# 20   -0.029804  0.006911    -0.027776
# 21    0.035206 -0.010172     0.008450
# 22    0.092600  0.031936     0.105244
#
# [372 rows x 942 columns]

# %% [markdown]
# ### T-test & FDR ###

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
pvals
# Out:
# array([0.86301361, 0.2210968 , 0.51254288, 0.14047335, 0.59395843,
#        0.59135277, 0.28849313])

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False])

# %% [markdown]
# ## Structural Connectivity ##

# %%
#set diagonal to be nan
x1 = sc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = sc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %% [markdown]
# ### Average SC per network - group differences ###

# %%
x1 = np.nanmean(x1,axis=2)
x2 = np.nanmean(x2,axis=2)

# %%
x2.shape
# Out:
# (23, 7)

# %%
#add SC network avgs to tabular df

data_={'HCP':x1,'LOBE':x2}

df_list=[]
for dataset in datasets:

    
    df_=pd.DataFrame(data_[dataset],
                 columns=('NSC_'+df_network_names))
    
    df_tabular_ = df_tabular.query(f"dataset == '{dataset}'")
    if dataset == 'HCP':
        df_['participant_id'] = hacky_hcp_subjects
    else:
        df_['participant_id'] = list(df_tabular_['participant_id'])
    
    
    df_merged_ = pd.merge(df_tabular_,df_,how='left',on='participant_id')
    df_list.append(df_merged_)

df_tabular = pd.concat(df_list)

# %%
print(df_tabular)
# Out:
#     participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0   sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1   sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2   sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3   sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4   sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..             ...     ...        ...  ..        ...          ...   ...
# 18         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 19         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 20         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 21         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 22         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#    focal_seizure_type  generalized_seizures  dre  ...  NFC_Limbic  NFC_Cont  \
# 0                 NaN                   NaN  NaN  ...    0.200019  0.257366
# 1                 NaN                   NaN  NaN  ...   -0.000347  0.147511
# 2                 NaN                   NaN  NaN  ...    0.093052  0.082952
# 3                 NaN                   NaN  NaN  ...   -0.001980 -0.008243
# 4                 NaN                   NaN  NaN  ...    0.091706  0.153798
# ..                ...                   ...  ...  ...         ...       ...
# 18              motor                   1.0  0.0  ...    0.467955  0.392260
# 19              motor                   0.0  NaN  ...    0.228163  0.205326
# 20          non-motor                   1.0  1.0  ...   -0.029804  0.006911
# 21              motor                   1.0  0.0  ...    0.035206 -0.010172
# 22              motor                   0.0  1.0  ...    0.092600  0.031936
#
#     NFC_Default   NSC_Vis  NSC_SomMot  NSC_DorsAttn  NSC_SalVentAttn  \
# 0      0.135539  3.885010    5.062987      8.027959         7.580041
# 1      0.039930  4.216869    4.518716      7.629381         7.669835
# 2      0.052142  4.770188    4.651514      8.898358         7.785734
# 3      0.010302  4.030981    4.773803      8.804379         7.742067
# 4      0.082643  4.350406    4.851836      9.014367         7.819415
# ..          ...       ...         ...           ...              ...
# 18     0.372756  4.093281    4.358512      7.515517         7.141540
# 19     0.162994  4.788529    5.042807      8.379897         7.876680
# 20    -0.027776  4.030132    4.791794      7.306059         7.469537
# 21     0.008450  4.027565    4.504583      7.768704         7.925532
# 22     0.105244  4.227500    5.029610      8.060599         7.408326
#
#     NSC_Limbic  NSC_Cont  NSC_Default
# 0     5.651460  7.296828     7.935002
# 1     6.542762  7.380725     8.132475
# 2     6.827971  7.798882     8.109647
# 3     6.960907  8.298339     8.540095
# 4     6.471102  8.094806     8.193476
# ..         ...       ...          ...
# 18    6.457969  6.372687     7.238880
# 19    7.567836  8.409854     8.806705
# 20    6.275113  7.390206     8.429542
# 21    6.047853  7.735365     8.119764
# 22    5.981137  7.941198     8.547162
#
# [372 rows x 949 columns]

# %% [markdown]
# ### T-test & FDR ###

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
pvals
# Out:
# array([0.26405605, 0.05325768, 0.11895523, 0.08753572, 0.23204956,
#        0.78405063, 0.57810951])

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False])

# %% [markdown]
# ### Save regional and network SFC, SC & FC to masterlist ###

# %%
#df_tabular.to_csv('results/analysis/df_tabular.csv',sep='\t',index=False)


df_tabular
# Out:
#     participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0   sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1   sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2   sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3   sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4   sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..             ...     ...        ...  ..        ...          ...   ...
# 18         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 19         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 20         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 21         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 22         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#    focal_seizure_type  generalized_seizures  dre  ...  NFC_Limbic  NFC_Cont  \
# 0                 NaN                   NaN  NaN  ...    0.200019  0.257366
# 1                 NaN                   NaN  NaN  ...   -0.000347  0.147511
# 2                 NaN                   NaN  NaN  ...    0.093052  0.082952
# 3                 NaN                   NaN  NaN  ...   -0.001980 -0.008243
# 4                 NaN                   NaN  NaN  ...    0.091706  0.153798
# ..                ...                   ...  ...  ...         ...       ...
# 18              motor                   1.0  0.0  ...    0.467955  0.392260
# 19              motor                   0.0  NaN  ...    0.228163  0.205326
# 20          non-motor                   1.0  1.0  ...   -0.029804  0.006911
# 21              motor                   1.0  0.0  ...    0.035206 -0.010172
# 22              motor                   0.0  1.0  ...    0.092600  0.031936
#
#     NFC_Default   NSC_Vis  NSC_SomMot  NSC_DorsAttn  NSC_SalVentAttn  \
# 0      0.135539  3.885010    5.062987      8.027959         7.580041
# 1      0.039930  4.216869    4.518716      7.629381         7.669835
# 2      0.052142  4.770188    4.651514      8.898358         7.785734
# 3      0.010302  4.030981    4.773803      8.804379         7.742067
# 4      0.082643  4.350406    4.851836      9.014367         7.819415
# ..          ...       ...         ...           ...              ...
# 18     0.372756  4.093281    4.358512      7.515517         7.141540
# 19     0.162994  4.788529    5.042807      8.379897         7.876680
# 20    -0.027776  4.030132    4.791794      7.306059         7.469537
# 21     0.008450  4.027565    4.504583      7.768704         7.925532
# 22     0.105244  4.227500    5.029610      8.060599         7.408326
#
#     NSC_Limbic  NSC_Cont  NSC_Default
# 0     5.651460  7.296828     7.935002
# 1     6.542762  7.380725     8.132475
# 2     6.827971  7.798882     8.109647
# 3     6.960907  8.298339     8.540095
# 4     6.471102  8.094806     8.193476
# ..         ...       ...          ...
# 18    6.457969  6.372687     7.238880
# 19    7.567836  8.409854     8.806705
# 20    6.275113  7.390206     8.429542
# 21    6.047853  7.735365     8.119764
# 22    5.981137  7.941198     8.547162
#
# [372 rows x 949 columns]

# %% [markdown]
# # Taking clinical phenotypes into account #

# %% [markdown]
# ## Temporal EEG Localization vs Non-Temporal ##

# %%
df_clinical = pd.read_table('clinical/participants.tsv')

temporal = df_clinical[df_clinical["loc_eeg_temporal"] == 1]
nontemporal = df_clinical[df_clinical["loc_eeg_temporal"] != 1]

df_temporal = temporal["participant_id"]
df_nontemporal = nontemporal["participant_id"]

# %%
print(df_nontemporal)
# Out:
# 0     sub-006
# 3     sub-010
# 8     sub-017
# 10    sub-020
# 11    sub-021
# 12    sub-022
# 13    sub-024
# 16    sub-027
# 17    sub-029
# 18    sub-031
# 19    sub-033
# 21    sub-038
# Name: participant_id, dtype: object
