# %%
import pandas as pd
df = pd.read_csv('results/combined/hippunfold/group-all_desc-subfields_atlas-bigbrain_volumes.tsv',sep='\t')

# %%
df
# Out:
#             subject hemi         Sub          CA1         CA2         CA3  \
# 0    sub-HCD0001305    L  573.687622  1067.657150  128.544369  373.789453
# 1    sub-HCD0001305    R  596.904584  1071.797101  127.431404  359.000299
# 2    sub-HCD0021614    L  571.353030  1145.452174  122.359716  349.902482
# 3    sub-HCD0021614    R  523.067381   972.346985  136.597655  304.500379
# 4    sub-HCD0026119    L  566.148912   789.724179   89.243034  346.545114
# ..              ...  ...         ...          ...         ...         ...
# 725         sub-020    R  425.008516   903.959512   92.718877  257.739577
# 726         sub-021    L  445.780564   904.778897  115.343963  310.835466
# 727         sub-021    R  391.132077   899.427937  104.755507  252.966735
# 728         sub-022    L  453.985860   786.083395  122.690825  320.167031
# 729         sub-022    R  391.014833   848.898603  103.821417  273.472793
#
#             CA4          DG        SRLM       Cyst dataset
# ...

# %%
import seaborn as sns

# %%
sns.stripplot(df,x='dataset',y='CA1',hue='hemi')
# Out:
# <Axes: xlabel='dataset', ylabel='CA1'>

# %%
sns.scatterplot(data=df,x='CA1',y='DG',hue='dataset')
# Out:
# <Axes: xlabel='CA1', ylabel='DG'>
