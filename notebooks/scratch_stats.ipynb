# %%
import pandas as pd
import nibabel as nib
from glob import glob
import numpy as np
import statsmodels.api as sp
#imported the full paths since it wasn't working otherwise - not sure why 
from statsmodels.stats.weightstats import ttest_ind
from statsmodels.stats.multitest import fdrcorrection
from statsmodels.regression.linear_model import OLS

# %%
# read in df_tabular with regional and network based data 

df_tabular = pd.read_csv('results/analysis/df_tabular.csv',sep='\t')

# %%
#just get LOBE dataset 
df_LOBE = df_tabular[df_tabular["dataset"] == "LOBE"]

# %%
df_LOBE
# Out:
#     participant_id dataset   age sex  age_onset  ep_duration  pnes  \
# 349        sub-006    LOBE   9.0   M        8.0          1.0   0.0
# 350        sub-007    LOBE   9.0   F        7.0          2.0   0.0
# 351        sub-009    LOBE   8.0   M        8.0          0.0   0.0
# 352        sub-010    LOBE  15.0   M        7.0          8.0   0.0
# 353        sub-012    LOBE  14.0   F        4.0         10.0   0.0
# 354        sub-013    LOBE  15.0   F       13.0          2.0   0.0
# 355        sub-014    LOBE  14.0   M        9.0          5.0   0.0
# 356        sub-015    LOBE  10.0   M        7.0          3.0   0.0
# 357        sub-017    LOBE  15.0   F       10.0          5.0   0.0
# 358        sub-019    LOBE  17.0   F       16.0          1.0   0.0
# 359        sub-020    LOBE  15.0   F        9.0          6.0   0.0
# 360        sub-021    LOBE  18.0   F       15.0          3.0   1.0
# 361        sub-022    LOBE  11.0   F        5.0          6.0   0.0
# 362        sub-024    LOBE  11.0   M        8.0          3.0   0.0
# 363        sub-025    LOBE  18.0   F        8.0         10.0   0.0
# 364        sub-026    LOBE  16.0   M       12.0          4.0   0.0
# 365        sub-027    LOBE   7.0   M        4.0          3.0   0.0
# 366        sub-029    LOBE  16.0   M       15.0          1.0   0.0
# 367        sub-031    LOBE   9.0   M        4.0          5.0   0.0
# 368        sub-033    LOBE   7.0   M        4.0          3.0   0.0
# 369        sub-035    LOBE   7.0   M        2.0          5.0   0.0
# 370        sub-038    LOBE  10.0   F        7.0          3.0   0.0
#
#     focal_seizure_type  generalized_seizures  dre  ...  NFC_Limbic  NFC_Cont  \
# 349              motor                   1.0  NaN  ...    0.242738  0.337645
# 350              motor                   0.0  1.0  ...    0.039989  0.055922
# 351              motor                   0.0  1.0  ...    0.147737  0.221310
# 352          non-motor                   0.0  0.0  ...    0.090205  0.100796
# 353          non-motor                   1.0  NaN  ...    0.100053  0.078775
# 354          non-motor                   0.0  NaN  ...    0.098577  0.111910
# 355          non-motor                   1.0  NaN  ...    0.163124  0.184982
# 356              motor                   NaN  NaN  ...    0.088092  0.083745
# 357          non-motor                   1.0  1.0  ...    0.139618  0.212389
# 358          non-motor                   1.0  NaN  ...    0.097342  0.059264
# 359          non-motor                   1.0  1.0  ...    0.043989  0.049989
# 360          non-motor                   0.0  NaN  ...    0.103501  0.101559
# 361              motor                   0.0  1.0  ...    0.178639  0.165187
# 362          non-motor                   1.0  0.0  ...    0.047968  0.071809
# 363          non-motor                   0.0  NaN  ...    0.175493  0.163257
# 364              motor                   1.0  1.0  ...    0.227521  0.288980
# 365          non-motor                   0.0  0.0  ...    0.075469  0.067642
# 366              motor                   1.0  0.0  ...    0.467955  0.392260
# 367              motor                   0.0  NaN  ...    0.228163  0.205326
# 368          non-motor                   1.0  1.0  ...   -0.029804  0.006911
# 369              motor                   1.0  0.0  ...    0.035206 -0.010172
# 370              motor                   0.0  1.0  ...    0.092600  0.031936
#
#      NFC_Default   NSC_Vis  NSC_SomMot  NSC_DorsAttn  NSC_SalVentAttn  \
# 349     0.289935  4.158078    4.446592      7.468249         7.537788
# 350     0.013673  4.174113    4.580525      7.659050         7.325782
# 351     0.161172  4.737190    4.914379      8.178362         7.942970
# 352     0.137763  4.866766    4.790801      8.518090         7.772193
# 353     0.079218  4.437935    5.252311      8.316320         7.973676
# 354    -0.060181  4.385528    4.652948      8.115841         8.079767
# 355     0.137038  3.913295    4.390988      7.457189         7.216438
# 356     0.146137  4.796880    4.806006      8.220487         8.515590
# 357     0.068701  4.347981    4.867421      8.900930         7.741240
# 358     0.031013  4.358916    4.771967      8.550381         8.033343
# 359     0.042028  4.288434    4.361288      8.094324         6.844981
# 360     0.026184  4.519417    5.023223      8.450988         7.397136
# 361     0.153321  4.730553    4.682737      7.600027         8.009516
# 362     0.008057  3.899524    4.560027      7.501978         8.079850
# 363     0.122207  4.806654    4.725796      9.371523         7.685026
# 364     0.300018  4.801931    4.610357      8.169396         7.943099
# 365     0.054453  4.802258    4.552375      7.560959         7.434806
# 366     0.372756  4.093281    4.358512      7.515517         7.141540
# 367     0.162994  4.788529    5.042807      8.379897         7.876680
# 368    -0.027776  4.030132    4.791794      7.306059         7.469537
# 369     0.008450  4.027565    4.504583      7.768704         7.925532
# 370     0.105244  4.227500    5.029610      8.060599         7.408326
#
#      NSC_Limbic  NSC_Cont  NSC_Default
# 349    6.113632  7.097794     7.533409
# 350    6.373010  7.850586     8.161856
# 351    6.717391  7.934972     8.000003
# 352    6.823215  7.446570     7.673076
# 353    5.279316  7.798454     7.919612
# 354    6.332022  6.787390     8.240192
# 355    5.839379  6.931214     6.931229
# 356    6.897235  7.125103     8.940187
# 357    6.696177  8.214334     8.586060
# 358    6.900780  8.004336     8.213125
# 359    6.116316  7.212081     7.177974
# 360    6.825194  7.516034     8.275988
# 361    6.406857  7.445807     8.088465
# 362    4.942950  6.974796     8.101657
# 363    6.769417  7.447820     7.901872
# 364    6.885443  7.456556     8.203762
# 365    6.626091  7.004652     7.430482
# 366    6.457969  6.372687     7.238880
# 367    7.567836  8.409854     8.806705
# 368    6.275113  7.390206     8.429542
# 369    6.047853  7.735365     8.119764
# 370    5.981137  7.941198     8.547162
#
# [22 rows x 949 columns]

# %%
#get temporal and nontemporal groups
temporal = df_LOBE[df_LOBE["loc_eeg_temporal"] == 1]
nontemporal = df_LOBE[df_LOBE["loc_eeg_temporal"] != 1]

#make sure pulling right subs
df_temporal = temporal["participant_id"]
df_nontemporal = nontemporal["participant_id"]

print(df_temporal)
# Out:
# 350    sub-007
# 351    sub-009
# 353    sub-012
# 354    sub-013
# 355    sub-014
# 356    sub-015
# 358    sub-019
# 363    sub-025
# 364    sub-026
# 369    sub-035
# Name: participant_id, dtype: object

# %%
x1 = temporal["NSFC_DorsAttn"]
x2 = nontemporal["NSFC_DorsAttn"]

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
pvals
# Out:
# 0.018448967504940048

# %%
#get motor and nonmotor groups
motor = df_LOBE[df_LOBE["focal_seizure_type"] == "motor"]
nonmotor = df_LOBE[df_LOBE["focal_seizure_type"] != "motor"]

#make sure pulling right subs
df_motor = motor["participant_id"]
df_nonmotor = nonmotor["participant_id"]

print(df_nonmotor)
# Out:
# 352    sub-010
# 353    sub-012
# 354    sub-013
# 355    sub-014
# 357    sub-017
# 358    sub-019
# 359    sub-020
# 360    sub-021
# 362    sub-024
# 363    sub-025
# 365    sub-027
# 368    sub-033
# Name: participant_id, dtype: object

# %%
x1 = motor["NSC_SomMot"]
x2 = nonmotor["NSC_SomMot"]

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
pvals
# Out:
# 0.7746711076604857

# %%
#get dre and nondre groups
dre = df_LOBE[df_LOBE["dre"] == 1]
nondre = df_LOBE[df_LOBE["dre"] != 1]

#make sure pulling right subs
df_dre = dre["participant_id"]
df_nondre = nondre["participant_id"]

print(df_nondre)
# Out:
# 349    sub-006
# 352    sub-010
# 353    sub-012
# 354    sub-013
# 355    sub-014
# 356    sub-015
# 358    sub-019
# 360    sub-021
# 362    sub-024
# 363    sub-025
# 365    sub-027
# 366    sub-029
# 367    sub-031
# 369    sub-035
# Name: participant_id, dtype: object

# %%
x1 = dre["NSC_SalVentAttn"]
x2 = nondre["NSC_SalVentAttn"]

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
pvals
# Out:
# 0.3185015225457177

# %%
#get generalized seizure and nongeneralized groups
gen = df_LOBE[df_LOBE["generalized_seizures"] == 1]
nongen = df_LOBE[df_LOBE["generalized_seizures"] != 1]

#make sure pulling right subs
df_gen = gen["participant_id"]
df_nongen = nongen["participant_id"]

print(df_gen)
# Out:
# 349    sub-006
# 353    sub-012
# 355    sub-014
# 357    sub-017
# 358    sub-019
# 359    sub-020
# 362    sub-024
# 364    sub-026
# 366    sub-029
# 368    sub-033
# 369    sub-035
# Name: participant_id, dtype: object

# %%
x1 = gen["NFC_SomMot"]
x2 = nongen["NFC_SomMot"]

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
pvals
# Out:
# 0.7986519725951767

# %%
#get female and male groups
female = df_LOBE[df_LOBE["sex"] == "F"]
male = df_LOBE[df_LOBE["sex"] == "M"]

#make sure pulling right subs
df_female = female["participant_id"]
df_male = male["participant_id"]

print(df_male)
# Out:
# 349    sub-006
# 351    sub-009
# 352    sub-010
# 355    sub-014
# 356    sub-015
# 362    sub-024
# 364    sub-026
# 365    sub-027
# 366    sub-029
# 367    sub-031
# 368    sub-033
# 369    sub-035
# Name: participant_id, dtype: object

# %%
x1 = female["NFC_SalVentAttn"]
x2 = male["NFC_SalVentAttn"]

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
pvals
# Out:
# 0.34685893640229604

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)
rejectedparticipant_id 	dataset 	age 	sex 	age_seizure_onset 	age_ep_diagnosis 	ep_duration_first_scan 	seizure_duration_first_scan 	pnes 	benign_rolandic 	... 	NFC_Limbic 	NFC_Cont 	NFC_Default 	NSC_Vis 	NSC_SomMot 	NSC_DorsAttn 	NSC_SalVentAttn 	NSC_Limbic 	NSC_Cont 	NSC_Default
341 	sub-004 	LOBE 	NaN 	NaN 	NaN 	NaN 	NaN 	NaN 	NaN 	NaN 	... 	0.018775 	0.041168 	0.005356 	4.579539 	4.814665 	8.650834 	7.161025 	6.553801 	7.372455 	8.310777
342 	sub-006 	LOBE 	9.0 	M 	7.0 	8.0 	1.0 	2.0 	0.0 	0.0 	... 	0.242738 	0.337645 	0.289935 	4.145457 	4.446113 	7.507796 	7.520987 	6.103175 	7.077718 	7.506009
343 	sub-007 	LOBE 	9.0 	F 	7.0 	7.0 	2.0 	2.0 	0.0 	0.0 	... 	0.040016 	0.055915 	0.013688 	4.204648 	4.599075 	7.685924 	7.358690 	6.379661 	7.868797 	8.170206
344 	sub-009 	L
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)
#       2 rejected
#
# File /localscratch/.cache/pypoetry/virtualenvs/lobe-analysis-fL6lcqD_-py3.11/lib/python3.11/site-packages/statsmodels/stats/multitest.py:332, in fdrcorrection(pvals, alpha, method, is_sorted)
#     281 '''
#     282 pvalue correction for false discovery rate.
#     283
#    (...)
#     329
#     330 '''
#     331 pvals = np.asarray(pvals)
# --> 332 assert pvals.ndim == 1, "pvals must be 1-dimensional, that is of shape (n,)"
#     334 if not is_sorted:
#     335     pvals_sortind = np.argsort(pvals)
#
# AssertionError: pvals must be 1-dimensional, that is of shape (n,)

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
#      participant_id dataset        age sex  age_onset  ep_duration  pnes  \
# 0    sub-HCD0001305     HCP  11.916667   M        NaN          NaN   NaN
# 1    sub-HCD0021614     HCP   9.166667   F        NaN          NaN   NaN
# 2    sub-HCD0026119     HCP  15.166667   F        NaN          NaN   NaN
# 3    sub-HCD0041822     HCP  17.416667   M        NaN          NaN   NaN
# 4    sub-HCD0042420     HCP  18.333333   M        NaN          NaN   NaN
# ..              ...     ...        ...  ..        ...          ...   ...
# 367         sub-029    LOBE  16.000000   M       15.0          1.0   0.0
# 368         sub-031    LOBE   9.000000   M        4.0          5.0   0.0
# 369         sub-033    LOBE   7.000000   M        4.0          3.0   0.0
# 370         sub-035    LOBE   7.000000   M        2.0          5.0   0.0
# 371         sub-038    LOBE  10.000000   F        7.0          3.0   0.0
#
#     focal_seizure_type  generalized_seizures  dre  ...  NFC_Limbic  NFC_Cont  \
# 0                  NaN                   NaN  NaN  ...    0.200019  0.257366
# 1                  NaN                   NaN  NaN  ...   -0.000347  0.147511
# 2                  NaN                   NaN  NaN  ...    0.093052  0.082952
# 3                  NaN                   NaN  NaN  ...   -0.001980 -0.008243
# 4                  NaN                   NaN  NaN  ...    0.091706  0.153798
# ..                 ...                   ...  ...  ...         ...       ...
# 367              motor                   1.0  0.0  ...    0.467955  0.392260
# 368              motor                   0.0  NaN  ...    0.228163  0.205326
# 369          non-motor                   1.0  1.0  ...   -0.029804  0.006911
# 370              motor                   1.0  0.0  ...    0.035206 -0.010172
# 371              motor                   0.0  1.0  ...    0.092600  0.031936
#
#      NFC_Default   NSC_Vis  NSC_SomMot  NSC_DorsAttn  NSC_SalVentAttn  \
# 0       0.135539  3.885010    5.062987      8.027959         7.580041
# 1       0.039930  4.216869    4.518716      7.629381         7.669835
# 2       0.052142  4.770188    4.651514      8.898358         7.785734
# 3       0.010302  4.030981    4.773803      8.804379         7.742067
# 4       0.082643  4.350406    4.851836      9.014367         7.819415
# ..           ...       ...         ...           ...              ...
# 367     0.372756  4.093281    4.358512      7.515517         7.141540
# 368     0.162994  4.788529    5.042807      8.379897         7.876680
# 369    -0.027776  4.030132    4.791794      7.306059         7.469537
# 370     0.008450  4.027565    4.504583      7.768704         7.925532
# 371     0.105244  4.227500    5.029610      8.060599         7.408326
#
#      NSC_Limbic  NSC_Cont  NSC_Default
# 0      5.651460  7.296828     7.935002
# 1      6.542762  7.380725     8.132475
# 2      6.827971  7.798882     8.109647
# 3      6.960907  8.298339     8.540095
# 4      6.471102  8.094806     8.193476
# ..          ...       ...          ...
# 367    6.457969  6.372687     7.238880
# 368    7.567836  8.409854     8.806705
# 369    6.275113  7.390206     8.429542
# 370    6.047853  7.735365     8.119764
# 371    5.981137  7.941198     8.547162
#
# [372 rows x 949 columns]

# %%
fc_pattern='results/{dataset}/sub-{subject}/func/sub-{subject}_task-rest_den-32k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-schaefer_bold.pconn.nii'
sc_pattern='results/{dataset}/sub-{subject}/dwi/sub-{subject}_den-32k_atlas-schaefer_struc.pconn.nii'
sfc_pattern='results/{dataset}/sub-{subject}/func/sub-{subject}_task-rest_den-32k_desc-preproc_denoise-24HMP8PhysSpikeReg_fwhm-5_atlas-schaefer_sfc.pscalar.nii'


datasets=['HCP','LOBE']

# %%
sfc_paths={}
sfc_paths['HCP'] = sorted(glob(sfc_pattern.format(dataset='HCP',subject='*')))
sfc_paths['LOBE'] = sorted(glob(sfc_pattern.format(dataset='LOBE',subject='*')))

fc_paths={}
fc_paths['HCP'] = sorted(glob(fc_pattern.format(dataset='HCP',subject='*')))
fc_paths['LOBE'] = sorted(glob(fc_pattern.format(dataset='LOBE',subject='*')))

sc_paths={}
sc_paths['HCP'] = sorted(glob(sc_pattern.format(dataset='HCP',subject='*')))
sc_paths['LOBE'] = sorted(glob(sc_pattern.format(dataset='LOBE',subject='*')))

#print(sfc_paths)
#print(fc_paths)
#print(sc_paths)

# %%
sfc={}
fc={}
sc={}
num_parcels = nib.load(sfc_paths['LOBE'][0]).get_fdata().shape[1]

for dataset in datasets:
    sfc[dataset] = np.concatenate(  [ nib.load(path).get_fdata()  for path in sfc_paths[dataset]] ,axis=0)
    fc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in fc_paths[dataset]] ,axis=0)
    sc[dataset] = np.concatenate(  [ nib.load(path).get_fdata().reshape((1,num_parcels,num_parcels))  for path in sc_paths[dataset]] ,axis=0)

# %% [markdown]
# ## SFC T-test and FDR - LOBE vs HCP

# %%
sfc['LOBE'].shape

# %%
x1 = sfc['HCP']
x2 = sfc['LOBE']

# %%
x2.shape
# Out:
# (14, 300)

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
# (300,)

# %%
pvals
# Out:
# array([1.70699709e-01, 1.78824864e-01, 2.26960136e-01, 1.88559300e-01,
#        5.66890299e-01, 6.14631760e-01, 2.51952273e-01, 6.33617811e-01,
#        4.13519648e-01, 7.38789719e-01, 8.39075179e-01, 1.03768428e-01,
#        1.49555553e-01, 7.08002286e-01, 3.33001362e-01, 7.75473839e-01,
#        2.85164578e-01, 2.14727308e-01, 5.78901077e-01, 5.89053450e-01,
#        6.43934225e-02, 7.63964296e-02, 8.08575307e-03, 3.11774055e-04,
#        8.87974178e-01, 7.75437313e-01, 9.24945788e-01, 2.60681315e-01,
#        4.10744700e-01, 1.53628551e-01, 5.92039347e-01, 1.62312334e-01,
#        8.60003899e-01, 4.21485002e-02, 4.13560234e-01, 8.06349544e-02,
#        1.08980301e-02, 2.69804073e-01, 1.11270406e-01, 3.41460786e-02,
#        6.03697259e-01, 5.46079259e-01, 4.87668753e-01, 1.27429067e-01,
#        1.33117458e-01, 5.25288761e-01, 3.95303180e-01, 3.23160883e-01,
#        3.27658719e-02, 1.02608151e-01, 3.16066632e-01, 5.67082663e-01,
#        7.53478841e-01, 8.17526421e-01, 8.78900322e-01, 4.71310760e-01,
#        8.53185212e-01, 2.49797242e-01, 4.21737385e-01, 7.36567716e-01,
#        5.87597238e-02, 7.69336039e-01, 6.63190063e-01, 9.21905705e-01,
#        5.99872073e-01, 9.40517231e-02, 4.15347189e-01, 1.52562340e-01,
#        1.97973412e-01, 2.51733322e-01, 8.56199759e-01, 4.36353463e-02,
#        3.20562779e-01, 2.67604060e-01, 2.30642372e-01, 9.23747716e-01,
#        6.73311799e-01, 6.22627011e-01, 9.03017607e-01, 4.30632117e-01,
#        6.86526715e-01, 9.83746587e-02, 2.32066469e-01, 5.30968081e-01,
#        1.44865321e-01, 1.10609490e-01, 5.11251026e-01, 8.81909716e-01,
#        6.99035003e-02, 5.95733199e-01, 9.38152686e-02, 7.84620928e-03,
#        1.47102746e-01, 7.21342622e-04, 2.15584141e-01, 9.59780305e-01,
#        8.35969530e-01, 9.35838545e-01, 7.24468861e-01, 7.53032860e-01,
#        7.29919600e-01, 2.33636933e-01, 4.66199922e-02, 8.42062876e-01,
#        8.42589955e-01, 8.97297619e-01, 8.53835168e-01, 5.31209915e-01,
#        9.83675929e-01, 7.08137240e-01, 2.62319034e-01, 4.92567630e-01,
#        3.05622391e-01, 9.25132345e-01, 8.32391323e-01, 7.08445639e-03,
#        4.54741174e-01, 5.78219034e-01, 4.40994928e-01, 1.31329424e-01,
#        4.91962969e-01, 1.30037940e-01, 2.26370609e-01, 8.26623086e-01,
#        2.58443020e-01, 9.40887928e-01, 4.20686018e-01, 9.92621782e-02,
#        2.40113630e-01, 8.12973071e-01, 3.50058802e-01, 7.51020598e-01,
#        4.43204160e-01, 4.81922433e-02, 1.01252148e-01, 5.60939254e-01,
#        8.25094201e-01, 1.47955449e-01, 7.75862605e-01, 2.67073685e-01,
#        6.21250777e-01, 7.86628636e-01, 1.84359860e-01, 7.54369160e-01,
#        3.47675798e-01, 5.91797036e-01, 5.19065678e-01, 8.82306651e-01,
#        5.94537611e-01, 4.31715516e-01, 1.85320506e-02, 5.02468070e-03,
#        1.99379832e-01, 2.06193687e-01, 9.91290186e-01, 2.06085264e-01,
#        4.04594782e-01, 2.63176416e-01, 7.37653995e-01, 5.30986215e-01,
#        1.23535913e-04, 2.85250239e-01, 7.78619804e-01, 2.21754230e-01,
#        8.50679829e-01, 1.87050445e-01, 3.43657157e-01, 7.42842018e-01,
#        4.14755537e-01, 3.37136311e-01, 1.07814951e-01, 7.79128998e-01,
#        2.19510945e-03, 8.67685446e-01, 4.08435196e-01, 6.90033306e-01,
#        8.03387265e-01, 7.38986768e-02, 4.19533447e-01, 8.03701083e-01,
#        9.49867573e-02, 8.18639222e-01, 1.09024135e-01, 5.72341513e-01,
#        1.16006472e-01, 8.25626520e-02, 4.47049085e-05, 2.97899461e-01,
#        9.07509953e-02, 2.79623765e-01, 7.65112005e-01, 5.44109862e-02,
#        2.32973593e-01, 5.46558375e-01, 1.06208269e-01, 9.31078325e-01,
#        4.90940964e-01, 3.39831747e-01, 3.79698435e-02, 1.71136153e-02,
#        2.03135929e-01, 2.68740231e-03, 7.75115054e-01, 8.10938257e-01,
#        9.22441436e-01, 9.38160469e-01, 2.88954147e-01, 1.64717603e-02,
#        9.08014120e-01, 9.91958667e-01, 2.11984971e-01, 7.81179172e-01,
#        6.52778579e-01, 7.09195854e-01, 9.66982566e-01, 2.48149136e-02,
#        8.27073703e-02, 2.42169472e-02, 4.14212557e-01, 3.35880105e-01,
#        4.74157022e-01, 1.48633189e-01, 9.62724346e-01, 9.29341518e-01,
#        6.11242919e-01, 1.41540511e-01, 3.02490624e-02, 7.03462824e-01,
#        5.79209659e-01, 8.50350821e-01, 4.92106613e-01, 9.84569637e-01,
#        2.00633549e-01, 5.94829854e-01, 8.35316508e-01, 3.10145703e-01,
#        1.45477278e-02, 1.94087837e-01, 8.92783431e-01, 4.76565617e-01,
#        5.29210098e-01, 3.91105090e-02, 3.20781763e-04, 4.94361391e-02,
#        8.92423375e-01, 1.84021846e-02, 3.13419242e-01, 7.99173426e-01,
#        4.14268047e-01, 1.24036730e-01, 1.59795424e-01, 7.84189412e-01,
#        5.30793678e-01, 9.26778664e-01, 3.60711599e-01, 9.80633486e-01,
#        3.15828400e-01, 6.05933036e-01, 4.79374535e-01, 8.10958895e-01,
#        6.96154088e-01, 5.65546545e-01, 8.51680626e-01, 7.79565682e-01,
#        1.71305436e-01, 5.28614496e-01, 9.35934224e-01, 4.14028540e-01,
#        6.14854948e-01, 3.36767969e-01, 9.44736731e-01, 1.23023495e-01,
#        8.12611785e-01, 8.45670578e-01, 3.45870514e-01, 6.88946000e-01,
#        5.72101022e-01, 1.43470124e-01, 1.09804750e-02, 9.33633205e-02,
#        1.96631092e-01, 4.45153170e-01, 1.92835911e-01, 5.62732168e-01,
#        9.46310342e-01, 1.06620199e-01, 5.89092484e-01, 5.67395461e-01,
#        3.03900120e-01, 1.36864713e-01, 4.96650974e-01, 4.15010990e-01,
#        2.03601540e-01, 7.40828781e-01, 2.37931744e-01, 3.45613924e-01,
#        9.57435963e-01, 9.46650518e-01, 2.63252151e-01, 6.34155503e-01])

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
# FC avg per parcel, group difference
#set diagonal to be nan
x1 = fc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = fc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %%
x1.shape
# Out:
# (341, 300, 300)

# %%
x1 = np.nanmean(x1,axis=2)
x2 = np.nanmean(x2,axis=2)

# %%
x1.shape
# Out:
# (341, 300)

# %%
x2.shape
# Out:
# (14, 300)

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
# (300,)

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
# SC avg per parcel, group difference
#set diagonal to be nan
x1 = sc['HCP']
for s in range(x1.shape[0]):
    conn = x1[s,:,:]    
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x1[s,:,:] = conn

x2 = sc['LOBE']
for s in range(x2.shape[0]):
    conn = x2[s,:,:]
    mask = np.eye(num_parcels)
    conn[mask==1] = np.nan
    x2[s,:,:] = conn

# %%
x1.shape
# Out:
# (340, 300, 300)

# %%
x1 = np.nanmean(x1,axis=2)
x1.shape
x2 = np.nanmean(x2,axis=2)
x2.shape
# Out:
# (14, 300)

# %%
x1.shape
# Out:
# (341, 300)

# %%
x2.shape
# Out:
# (14, 300)

# %%
tstats,pvals,dfs = ttest_ind(x1, x2, alternative='two-sided', usevar='pooled', weights=(None, None), value=0)
tstats.shape
# Out:
# (300,)

# %%
rejected,corr_pvals = fdrcorrection(pvals, alpha=0.05, method='indep', is_sorted=False)

# %%
rejected
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %% [markdown]
# ## Linear Model - Taking Age and Sex into Account
