# %% [markdown]
# # Seperating tsv into left and right sided patients, ignoring bilateral patients

# %% [markdown]
# # Left = ipsi, Right = cont #

# %%
import pandas as pd

# Read the input TSV file
df = pd.read_csv('../resources/merged_tabular_withconn.tsv',sep='\t')

# %%
df
# Out:
#      participant_id dataset        age sex  age_seizure_onset  \
# 0    sub-HCD0001305     HCP  11.916667   M                NaN
# 1    sub-HCD0021614     HCP   9.166667   F                NaN
# 2    sub-HCD0026119     HCP  15.166667   F                NaN
# 3    sub-HCD0041822     HCP  17.416667   M                NaN
# 4    sub-HCD0042420     HCP  18.333333   M                NaN
# ..              ...     ...        ...  ..                ...
# 363         sub-035    LOBE   7.000000   M                2.0
# 364         sub-036    LOBE  15.000000   M               10.0
# 365         sub-038    LOBE  10.000000   F                7.0
# 366         sub-040    LOBE   9.000000   F                5.0
# 367         sub-041    LOBE  12.000000   M                4.0
#
#      age_ep_diagnosis  ep_duration_first_scan  seizure_duration_first_scan  \
# 0                 NaN                     NaN                          NaN
# 1                 NaN                     NaN                          NaN
# 2                 NaN                     NaN                          NaN
# 3                 NaN                     NaN                          NaN
# 4                 NaN                     NaN                          NaN
# ..                ...                     ...                          ...
# 363               4.0                     3.0                          5.0
# 364               NaN                     NaN                          5.0
# 365               7.0                     3.0                          3.0
# 366               NaN                     NaN                          4.0
# 367               NaN                     NaN                          8.0
#
#      pnes  benign_rolandic  ... NFC_L_SomMot_L_SalVentAttn  \
# 0     NaN              NaN  ...                   0.310307
# 1     NaN              NaN  ...                   0.489250
# 2     NaN              NaN  ...                   0.227592
# 3     NaN              NaN  ...                   0.200100
# 4     NaN              NaN  ...                   0.224646
# ..    ...              ...  ...                        ...
# 363   0.0              0.0  ...                   0.064866
# 364   NaN              NaN  ...                   0.097036
# 365   0.0              0.0  ...                   0.260492
# 366   NaN              NaN  ...                   0.258969
# 367   NaN              NaN  ...                   0.278112
#
#      NFC_L_SomMot_R_SalVentAttn  NFC_L_SomMot_L_Limbic  NFC_L_SomMot_R_Limbic  \
# 0                      0.274220               0.201991               0.166749
# 1                      0.484463               0.014686               0.019896
# 2                      0.160810               0.248390               0.137148
# 3                      0.143483              -0.010013              -0.004120
# 4                      0.195035               0.126603               0.180176
# ..                          ...                    ...                    ...
# 363                    0.098368               0.034367               0.061549
# 364                    0.034313              -0.033166              -0.036691
# 365                    0.213172               0.207996               0.114929
# 366                    0.325223               0.054323               0.060238
# 367                    0.241079               0.261178               0.253622
#
#      NFC_L_SomMot_L_Vis  NFC_L_SomMot_R_Vis  NFC_L_SomMot_L_Subcort  \
# 0             -0.044353           -0.055097                0.276603
# 1              0.345258            0.184133                0.485842
# 2              0.249743            0.266568                0.179634
# 3              0.038357            0.043799                0.117544
# 4              0.045052            0.046738                0.162806
# ..                  ...                 ...                     ...
# 363            0.379253            0.350227               -0.055624
# 364            0.032574            0.034385                0.087699
# 365            0.221618            0.215914                0.231875
# 366            0.160113            0.085077                0.125455
# 367            0.235186            0.204784                0.214460
#
#      NFC_L_SomMot_R_Subcort  NFC_R_SomMot_R_SomMot  NFC_R_SomMot_L_SalVentAttn
# 0                  0.194345               0.539150                    0.432403
# 1                  0.371566               0.330244                    0.428722
# 2                  0.195839               0.417886                    0.244905
# 3                  0.121745               0.316374                    0.076081
# 4                  0.156488               0.427641                    0.225524
# ..                      ...                    ...                         ...
# 363                0.014553               0.584103                    0.042578
# 364                0.063775               0.312651                    0.167129
# 365                0.193647               0.422314                    0.258001
# 366                0.350706               0.475052                    0.231110
# 367                0.196714               0.499693                    0.195385
#
# [368 rows x 1024 columns]

# %%
# Filter columns that contain '7Networks' in the column name
columns_to_drop = df.filter(regex='7Networks').columns

# Drop the identified columns from the DataFrame
df = df.drop(columns=columns_to_drop)

# Optionally, save the updated DataFrame back to a new TSV file
df.to_csv('../resources/merged_tabular_withconn_brainnetome.tsv', sep="\t", index=False)

# %%
df
# Out:
#      participant_id dataset        age sex  age_seizure_onset  \
# 0    sub-HCD0001305     HCP  11.916667   M                NaN
# 1    sub-HCD0021614     HCP   9.166667   F                NaN
# 2    sub-HCD0026119     HCP  15.166667   F                NaN
# 3    sub-HCD0041822     HCP  17.416667   M                NaN
# 4    sub-HCD0042420     HCP  18.333333   M                NaN
# ..              ...     ...        ...  ..                ...
# 363         sub-035    LOBE   7.000000   M                2.0
# 364         sub-036    LOBE  15.000000   M               10.0
# 365         sub-038    LOBE  10.000000   F                7.0
# 366         sub-040    LOBE   9.000000   F                5.0
# 367         sub-041    LOBE  12.000000   M                4.0
#
#      age_ep_diagnosis  ep_duration_first_scan  seizure_duration_first_scan  \
# 0                 NaN                     NaN                          NaN
# 1                 NaN                     NaN                          NaN
# 2                 NaN                     NaN                          NaN
# 3                 NaN                     NaN                          NaN
# 4                 NaN                     NaN                          NaN
# ..                ...                     ...                          ...
# 363               4.0                     3.0                          5.0
# 364               NaN                     NaN                          5.0
# 365               7.0                     3.0                          3.0
# 366               NaN                     NaN                          4.0
# 367               NaN                     NaN                          8.0
#
#      pnes  benign_rolandic  ... NFC_L_SomMot_L_SalVentAttn  \
# 0     NaN              NaN  ...                   0.310307
# 1     NaN              NaN  ...                   0.489250
# 2     NaN              NaN  ...                   0.227592
# 3     NaN              NaN  ...                   0.200100
# 4     NaN              NaN  ...                   0.224646
# ..    ...              ...  ...                        ...
# 363   0.0              0.0  ...                   0.064866
# 364   NaN              NaN  ...                   0.097036
# 365   0.0              0.0  ...                   0.260492
# 366   NaN              NaN  ...                   0.258969
# 367   NaN              NaN  ...                   0.278112
#
#      NFC_L_SomMot_R_SalVentAttn  NFC_L_SomMot_L_Limbic  NFC_L_SomMot_R_Limbic  \
# 0                      0.274220               0.201991               0.166749
# 1                      0.484463               0.014686               0.019896
# 2                      0.160810               0.248390               0.137148
# 3                      0.143483              -0.010013              -0.004120
# 4                      0.195035               0.126603               0.180176
# ..                          ...                    ...                    ...
# 363                    0.098368               0.034367               0.061549
# 364                    0.034313              -0.033166              -0.036691
# 365                    0.213172               0.207996               0.114929
# 366                    0.325223               0.054323               0.060238
# 367                    0.241079               0.261178               0.253622
#
#      NFC_L_SomMot_L_Vis  NFC_L_SomMot_R_Vis  NFC_L_SomMot_L_Subcort  \
# 0             -0.044353           -0.055097                0.276603
# 1              0.345258            0.184133                0.485842
# 2              0.249743            0.266568                0.179634
# 3              0.038357            0.043799                0.117544
# 4              0.045052            0.046738                0.162806
# ..                  ...                 ...                     ...
# 363            0.379253            0.350227               -0.055624
# 364            0.032574            0.034385                0.087699
# 365            0.221618            0.215914                0.231875
# 366            0.160113            0.085077                0.125455
# 367            0.235186            0.204784                0.214460
#
#      NFC_L_SomMot_R_Subcort  NFC_R_SomMot_R_SomMot  NFC_R_SomMot_L_SalVentAttn
# 0                  0.194345               0.539150                    0.432403
# 1                  0.371566               0.330244                    0.428722
# 2                  0.195839               0.417886                    0.244905
# 3                  0.121745               0.316374                    0.076081
# 4                  0.156488               0.427641                    0.225524
# ..                      ...                    ...                         ...
# 363                0.014553               0.584103                    0.042578
# 364                0.063775               0.312651                    0.167129
# 365                0.193647               0.422314                    0.258001
# 366                0.350706               0.475052                    0.231110
# 367                0.196714               0.499693                    0.195385
#
# [368 rows x 1024 columns]

# %%
# Filter the DataFrame
filtered_df = df[(df['lat_final_left'] == "1") & (df['lat_final_bilateral'] == 0)]

# Write the output TSV file
filtered_df.to_csv('../resources/tabular/tabular_withconn_left.tsv', sep='\t', index=False)

# %%
# Filter the DataFrame
filtered_df = df[(df['lat_final_right'] == "1") & (df['lat_final_bilateral'] == 0)]

# Write the output TSV file
filtered_df.to_csv('../resources/tabular/tabular_withconn_right.tsv', sep='\t', index=False)

# %%
df = pd.read_csv('../resources/tabular/tabular_withconn_left.tsv',sep='\t')

# Rename columns
df.columns = df.columns.str.replace('_L_', '_ipsi_', regex=False).str.replace('_R_', '_contra_', regex=False)

# Write the output TSV file
df.to_csv('../resources/tabular/tabular_withconn_left_renamed.tsv', sep='\t', index=False)

# %%
df = pd.read_csv('../resources/tabular/tabular_withconn_right.tsv',sep='\t')

# Rename columns
df.columns = df.columns.str.replace('_R_', '_ipsi_', regex=False).str.replace('_L_', '_contra_', regex=False)

# Write the output TSV file
df.to_csv('../resources/tabular/tabular_withconn_right_renamed.tsv', sep='\t', index=False)

# %%
# making a new tsv with just hcp so I can rename the columns

# Read the input TSV file
df = pd.read_csv('../resources/merged_tabular_withconn_brainnetome.tsv',sep='\t')

# Filter the DataFrame
filtered_df = df[df['dataset'] == 'HCP']

# Write the output TSV file
filtered_df.to_csv('../resources/tabular/tabular_withconn_hcp.tsv', sep='\t', index=False)

# %%
# rename HCP so that left = ipsi and right = contra

df = pd.read_csv('../resources/tabular/tabular_withconn_hcp.tsv',sep='\t')

# Rename columns
df.columns = df.columns.str.replace('_L_', '_ipsi_', regex=False).str.replace('_R_', '_contra_', regex=False)

# Write the output TSV file
df.to_csv('../resources/tabular/tabular_withconn_hcp_renamed.tsv', sep='\t', index=False)

# %%
# averaging left and right parcels to average across HCP

df = pd.read_csv('../resources/tabular/tabular_withconn_hcp_renamed.tsv',sep='\t')

# Loop over all columns to find pairs of 'ipsi' and 'contra' columns
for col in df.columns:
    # Split the column name into parts
    parts = col.split('_')
    
    # Ensure the column name has the expected format of 'prefix_side_suffix'
    if len(parts) == 4:
        prefix = parts[0]  # e.g., 'RSFC'
        side = parts[1]    # 'ipsi' or 'contra'
        suffix = parts[2]  # e.g., 'A8m'
        network = parts [3]
        
        # Create a base name (e.g., 'RSFC_A8m')
        base_name = f"{prefix}_{suffix}"
        
        # Check if the opposite side column exists
        opposite_side = 'ipsi' if side == 'contra' else 'contra'
        opposite_col = f"{prefix}_{opposite_side}_{suffix}_{network}"
        
        # If both 'ipsi' and 'contra' columns exist, average the values and overwrite them
        if opposite_col in df.columns:
            # Average the values of both columns
            df[col] = (df[col] + df[opposite_col]) / 2
            df[opposite_col] = df[col]  # Also set the opposite side column to the same value

# Now, df contains the averaged values in place of the original columns
df.head()  # Display the first few rows of the updated DataFrame


# Optionally, save the updated DataFrame back to a TSV file
df.to_csv('../resources/tabular/tabular_withconn_hcp_averaged.tsv',sep='\t', index=False)

# %%
# Get all unique columns from the three DataFrames
all_columns = set(df1.columns).union(set(df2.columns), set(df3.columns))

# Find missing columns in each DataFrame
missing_df1 = all_columns - set(df1.columns)
missing_df2 = all_columns - set(df2.columns)
missing_df3 = all_columns - set(df3.columns)

# Print missing columns
if missing_df1:
    print("Columns missing from df1:", missing_df1)
if missing_df2:
    print("Columns missing from df2:", missing_df2)
if missing_df3:
    print("Columns missing from df3:", missing_df3)



# Now concatenate
#combined_df = pd.concat([df1, df2, df3], ignore_index=True)
# Out:
# Columns missing from df1: {'NFC_contra_SomMot_contra_Limbic', 'NFC_ipsi_Subcort_contra_SomMot', 'NFC_contra_SalVentAttn_contra_SomMot', 'NFC_ipsi_Limbic_contra_SomMot', 'NFC_contra_Vis_contra_SomMot', 'NFC_contra_Subcort_contra_SomMot', 'NFC_contra_SomMot_ipsi_Vis'}
# Columns missing from df2: {'NFC_contra_SomMot_contra_Limbic', 'NFC_ipsi_Subcort_contra_SomMot', 'NFC_contra_SalVentAttn_contra_SomMot', 'NFC_ipsi_Limbic_contra_SomMot', 'NFC_contra_Vis_contra_SomMot', 'NFC_contra_Subcort_contra_SomMot', 'NFC_contra_SomMot_ipsi_Vis'}
# Columns missing from df3: {'NFC_ipsi_SomMot_contra_Limbic', 'NFC_ipsi_SomMot_ipsi_Vis', 'NFC_ipsi_SomMot_ipsi_Subcort', 'NFC_ipsi_SomMot_ipsi_SalVentAttn', 'NFC_ipsi_SomMot_contra_Vis', 'NFC_ipsi_SomMot_ipsi_Limbic', 'NFC_ipsi_SomMot_contra_Subcort'}

# %%
# put together hcp, left and right renamed

# Read the input TSV files
df1 = pd.read_csv('../resources/tabular/tabular_withconn_hcp_averaged.tsv', sep='\t')
df2 = pd.read_csv('../resources/tabular/tabular_withconn_left_renamed.tsv', sep='\t')
df3 = pd.read_csv('../resources/tabular/tabular_withconn_right_renamed.tsv', sep='\t')

# %%
import pandas as pd

# Define the specific columns that need to be fixed
columns_to_fix = {
    'NSFC_contra_Subcort_ipsi_Subcort', 'NSFC_contra_Default_ipsi_Default',
    'NSFC_contra_Limbic_ipsi_Limbic', 'NFC_contra_Cont_ipsi_Cont',
    'NSFC_contra_SalVentAttn_ipsi_SalVentAttn', 'NFC_contra_SomMot_contra_Vis',
    'NFC_contra_SomMot_ipsi_Subcort', 'NFC_contra_SomMot_contra_Subcort',
    'NFC_contra_SomMot_contra_SalVentAttn', 'NFC_contra_SomMot_ipsi_Limbic',
    'NSFC_contra_Vis_ipsi_Vis', 'NFC_contra_DorsAttn_ipsi_DorsAttn',
    'NFC_contra_Default_ipsi_Default', 'NFC_contra_SomMot_ipsi_Vis',
    'NFC_contra_SomMot_contra_Limbic', 'NSFC_contra_SomMot_ipsi_SomMot',
    'NSFC_contra_DorsAttn_ipsi_DorsAttn', 'NFC_contra_SomMot_ipsi_SomMot',
    'NSFC_contra_Cont_ipsi_Cont', 'NFC_ipsi_Subcort_contra_SomMot', 
    'NFC_contra_SalVentAttn_contra_SomMot', 'NFC_contra_Limbic_contra_SomMot', 
    'NFC_ipsi_Limbic_contra_SomMot', 'NFC_contra_Vis_contra_SomMot', 
    'NFC_contra_Subcort_contra_SomMot', 'NFC_ipsi_Vis_contra_SomMot'
}

# Function to swap parts of the column name
def rename_column(column_name):
    parts = column_name.split('_')
    
    # Ensure the column has 5 parts (or more if necessary)
    if len(parts) >= 5:
        # Swap the second and third parts with the fourth and fifth parts
        parts[1], parts[2], parts[3], parts[4] = parts[3], parts[4], parts[1], parts[2]
        
        # Rejoin the parts back into the column name
        return '_'.join(parts)
    else:
        # Return the original name if it doesn't have 5 parts
        return column_name


# Iterate through the columns to fix in df3 and apply renaming
for col in columns_to_fix:
    if col in df3.columns:
        new_name = rename_column(col)
        print(f"Renaming: {col} → {new_name}")
        df3.rename(columns={col: new_name}, inplace=True)

# Check if renaming worked by printing the updated column names
print("\nUpdated df3 columns after renaming:")
print(df3.columns)
# Out:
# Renaming: NFC_ipsi_Subcort_contra_SomMot → NFC_contra_SomMot_ipsi_Subcort
# Renaming: NFC_contra_Vis_contra_SomMot → NFC_contra_SomMot_contra_Vis
# Renaming: NFC_contra_Subcort_contra_SomMot → NFC_contra_SomMot_contra_Subcort
# Renaming: NFC_contra_SomMot_ipsi_Vis → NFC_ipsi_Vis_contra_SomMot
# Renaming: NFC_contra_SomMot_contra_Limbic → NFC_contra_Limbic_contra_SomMot
# Renaming: NFC_contra_SomMot_contra_Vis → NFC_contra_Vis_contra_SomMot
# Renaming: NFC_contra_SalVentAttn_contra_SomMot → NFC_contra_SomMot_contra_SalVentAttn
# Renaming: NFC_contra_Limbic_contra_SomMot → NFC_contra_SomMot_contra_Limbic
# Renaming: NFC_ipsi_Limbic_contra_SomMot → NFC_contra_SomMot_ipsi_Limbic
# Renaming: NFC_contra_SomMot_ipsi_Subcort → NFC_ipsi_Subcort_contra_SomMot
# Renaming: NFC_contra_SomMot_contra_Subcort → NFC_contra_Subcort_contra_SomMot
# Renaming: NFC_ipsi_Vis_contra_SomMot → NFC_contra_SomMot_ipsi_Vis
# Renaming: NFC_contra_SomMot_contra_SalVentAttn → NFC_contra_SalVentAttn_contra_SomMot
# Renaming: NFC_contra_SomMot_ipsi_Limbic → NFC_ipsi_Limbic_contra_SomMot
#
# Updated df3 columns after renaming:
# Index(['participant_id', 'dataset', 'age', 'sex', 'age_seizure_onset',
#        'age_ep_diagnosis', 'ep_duration_first_scan',
#        'seizure_duration_first_scan', 'pnes', 'benign_rolandic',
#        ...
#        'NFC_contra_SalVentAttn_contra_SomMot',
#        'NFC_contra_SomMot_ipsi_SalVentAttn', 'NFC_contra_SomMot_contra_Limbic',
#        'NFC_ipsi_Limbic_contra_SomMot', 'NFC_contra_Vis_contra_SomMot',
#        'NFC_contra_SomMot_ipsi_Vis', 'NFC_contra_Subcort_contra_SomMot',
#        'NFC_ipsi_Subcort_contra_SomMot', 'NFC_ipsi_SomMot_ipsi_SomMot',
#        'NFC_ipsi_SomMot_contra_SalVentAttn'],
#       dtype='object', length=1024)

# %%
df3
# Out:
#    participant_id dataset   age sex  age_seizure_onset  age_ep_diagnosis  \
# 0         sub-006    LOBE   9.0   M                7.0               8.0
# 1         sub-010    LOBE  15.0   M                7.0               7.0
# 2         sub-014    LOBE  14.0   M                9.0               9.0
# 3         sub-017    LOBE  15.0   F               10.0              10.0
# 4         sub-020    LOBE  15.0   F                8.0              10.0
# 5         sub-025    LOBE  18.0   F                8.0              17.0
# 6         sub-028    LOBE   8.0   F                3.0               NaN
# 7         sub-029    LOBE  16.0   M               15.0              15.0
# 8         sub-035    LOBE   7.0   M                2.0               4.0
# 9         sub-038    LOBE  10.0   F                7.0               7.0
# 10        sub-041    LOBE  12.0   M                4.0               NaN
#
#     ep_duration_first_scan  seizure_duration_first_scan  pnes  \
# 0                      1.0                          2.0   0.0
# 1                      8.0                          8.0   0.0
# 2                      5.0                          5.0   0.0
# 3                      5.0                          5.0   0.0
# 4                      5.0                          7.0   0.0
# 5                      1.0                         10.0   0.0
# 6                      NaN                          5.0   0.0
# 7                      1.0                          1.0   0.0
# 8                      3.0                          5.0   0.0
# 9                      3.0                          3.0   0.0
# 10                     NaN                          8.0   NaN
#
#     benign_rolandic  ... NFC_contra_SalVentAttn_contra_SomMot  \
# 0               0.0  ...                             0.507667
# 1               0.0  ...                             0.308687
# 2               0.0  ...                             0.368957
# 3               0.0  ...                             0.391438
# 4               0.0  ...                             0.269744
# 5               0.0  ...                             0.338671
# 6               0.0  ...                             0.253008
# 7               0.0  ...                             0.649497
# 8               0.0  ...                             0.064866
# 9               0.0  ...                             0.260492
# 10              NaN  ...                             0.278112
#
#     NFC_contra_SomMot_ipsi_SalVentAttn  NFC_contra_SomMot_contra_Limbic  \
# 0                             0.615260                         0.222434
# 1                             0.192000                         0.143737
# 2                             0.424496                         0.141265
# 3                             0.328023                         0.073425
# 4                             0.280759                         0.164479
# 5                             0.274711                         0.117809
# 6                             0.252404                         0.151578
# 7                             0.534696                         0.488039
# 8                             0.098368                         0.034367
# 9                             0.213172                         0.207996
# 10                            0.241079                         0.261178
#
#     NFC_ipsi_Limbic_contra_SomMot  NFC_contra_Vis_contra_SomMot  \
# 0                        0.297744                      0.426252
# 1                        0.065170                      0.373591
# 2                        0.178140                      0.372726
# 3                        0.095290                      0.204809
# 4                        0.081186                      0.042230
# 5                        0.200457                      0.154166
# 6                        0.079311                      0.390658
# 7                        0.434027                      0.290173
# 8                        0.061549                      0.379253
# 9                        0.114929                      0.221618
# 10                       0.253622                      0.235186
#
#     NFC_contra_SomMot_ipsi_Vis  NFC_contra_Subcort_contra_SomMot  \
# 0                     0.418372                          0.510923
# 1                     0.272360                          0.132701
# 2                     0.360009                          0.222630
# 3                     0.190421                          0.095152
# 4                     0.064834                          0.080972
# 5                     0.183682                          0.109284
# 6                     0.423512                          0.166954
# 7                     0.321879                          0.544352
# 8                     0.350227                         -0.055624
# 9                     0.215914                          0.231875
# 10                    0.204784                          0.214460
#
#     NFC_ipsi_Subcort_contra_SomMot  NFC_ipsi_SomMot_ipsi_SomMot  \
# 0                         0.426699                     0.664579
# 1                         0.018980                     0.311566
# 2                         0.248327                     0.569056
# 3                         0.045055                     0.409955
# 4                         0.033330                     0.457391
# 5                         0.100371                     0.607417
# 6                         0.098820                     0.347499
# 7                         0.491642                     0.710499
# 8                         0.014553                     0.584103
# 9                         0.193647                     0.422314
# 10                        0.196714                     0.499693
#
#     NFC_ipsi_SomMot_contra_SalVentAttn
# 0                             0.413329
# 1                             0.275089
# 2                             0.371938
# 3                             0.345694
# 4                             0.235499
# 5                             0.345265
# 6                             0.179136
# 7                             0.637989
# 8                             0.042578
# 9                             0.258001
# 10                            0.195385
#
# [11 rows x 1024 columns]

# %%
# Check the column names in each DataFrame
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['participant_id', 'dataset', 'age', 'sex', 'age_seizure_onset',
#        'age_ep_diagnosis', 'ep_duration_first_scan',
#        'seizure_duration_first_scan', 'pnes', 'benign_rolandic',
#        ...
#        'NFC_ipsi_SomMot_ipsi_SalVentAttn',
#        'NFC_ipsi_SomMot_contra_SalVentAttn', 'NFC_ipsi_SomMot_ipsi_Limbic',
#        'NFC_ipsi_SomMot_contra_Limbic', 'NFC_ipsi_SomMot_ipsi_Vis',
#        'NFC_ipsi_SomMot_contra_Vis', 'NFC_ipsi_SomMot_ipsi_Subcort',
#        'NFC_ipsi_SomMot_contra_Subcort', 'NFC_contra_SomMot_contra_SomMot',
#        'NFC_contra_SomMot_ipsi_SalVentAttn'],
#       dtype='object', length=1024)
# Index(['participant_id', 'dataset', 'age', 'sex', 'age_seizure_onset',
#        'age_ep_diagnosis', 'ep_duration_first_scan',
#        'seizure_duration_first_scan', 'pnes', 'benign_rolandic',
#        ...
#        'NFC_ipsi_SomMot_ipsi_SalVentAttn',
#        'NFC_ipsi_SomMot_contra_SalVentAttn', 'NFC_ipsi_SomMot_ipsi_Limbic',
#        'NFC_ipsi_SomMot_contra_Limbic', 'NFC_ipsi_SomMot_ipsi_Vis',
#        'NFC_ipsi_SomMot_contra_Vis', 'NFC_ipsi_SomMot_ipsi_Subcort',
#        'NFC_ipsi_SomMot_contra_Subcort', 'NFC_contra_SomMot_contra_SomMot',
#        'NFC_contra_SomMot_ipsi_SalVentAttn'],
#       dtype='object', length=1024)
# Index(['participant_id', 'dataset', 'age', 'sex', 'age_seizure_onset',
#        'age_ep_diagnosis', 'ep_duration_first_scan',
#        'seizure_duration_first_scan', 'pnes', 'benign_rolandic',
#        ...
#        'NFC_contra_SalVentAttn_contra_SomMot',
#        'NFC_contra_SomMot_ipsi_SalVentAttn', 'NFC_contra_SomMot_contra_Limbic',
#        'NFC_ipsi_Limbic_contra_SomMot', 'NFC_contra_Vis_contra_SomMot',
#        'NFC_contra_SomMot_ipsi_Vis', 'NFC_contra_Subcort_contra_SomMot',
#        'NFC_ipsi_Subcort_contra_SomMot', 'NFC_ipsi_SomMot_ipsi_SomMot',
#        'NFC_ipsi_SomMot_contra_SalVentAttn'],
#       dtype='object', length=1024)

# %%
# Now concatenate
combined_df = pd.concat([df1, df2, df3], ignore_index=True)

# %%
combined_df
# Out:
#      participant_id dataset        age sex  age_seizure_onset  \
# 0    sub-HCD0001305     HCP  11.916667   M                NaN
# 1    sub-HCD0021614     HCP   9.166667   F                NaN
# 2    sub-HCD0026119     HCP  15.166667   F                NaN
# 3    sub-HCD0041822     HCP  17.416667   M                NaN
# 4    sub-HCD0042420     HCP  18.333333   M                NaN
# ..              ...     ...        ...  ..                ...
# 357         sub-028    LOBE   8.000000   F                3.0
# 358         sub-029    LOBE  16.000000   M               15.0
# 359         sub-035    LOBE   7.000000   M                2.0
# 360         sub-038    LOBE  10.000000   F                7.0
# 361         sub-041    LOBE  12.000000   M                4.0
#
#      age_ep_diagnosis  ep_duration_first_scan  seizure_duration_first_scan  \
# 0                 NaN                     NaN                          NaN
# 1                 NaN                     NaN                          NaN
# 2                 NaN                     NaN                          NaN
# 3                 NaN                     NaN                          NaN
# 4                 NaN                     NaN                          NaN
# ..                ...                     ...                          ...
# 357               NaN                     NaN                          5.0
# 358              15.0                     1.0                          1.0
# 359               4.0                     3.0                          5.0
# 360               7.0                     3.0                          3.0
# 361               NaN                     NaN                          8.0
#
#      pnes  benign_rolandic  ... NFC_contra_Default_ipsi_Default  \
# 0     NaN              NaN  ...                             NaN
# 1     NaN              NaN  ...                             NaN
# 2     NaN              NaN  ...                             NaN
# 3     NaN              NaN  ...                             NaN
# 4     NaN              NaN  ...                             NaN
# ..    ...              ...  ...                             ...
# 357   0.0              0.0  ...                        0.124544
# 358   0.0              0.0  ...                        0.603187
# 359   0.0              0.0  ...                        0.272942
# 360   0.0              0.0  ...                        0.383027
# 361   NaN              NaN  ...                        0.285100
#
#      NFC_contra_DorsAttn_ipsi_DorsAttn  NFC_contra_SomMot_ipsi_SomMot  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ..                                 ...                            ...
# 357                           0.314289                       0.340230
# 358                           0.473829                       0.712617
# 359                           0.324812                       0.527174
# 360                           0.323572                       0.435330
# 361                           0.426443                       0.474698
#
#      NFC_contra_SomMot_contra_SalVentAttn  NFC_contra_SomMot_contra_Limbic  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
# ..                                    ...                              ...
# 357                              0.253008                         0.151578
# 358                              0.649497                         0.488039
# 359                              0.064866                         0.034367
# 360                              0.260492                         0.207996
# 361                              0.278112                         0.261178
#
#      NFC_contra_SomMot_ipsi_Limbic  NFC_contra_SomMot_contra_Vis  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ..                             ...                           ...
# 357                       0.079311                      0.390658
# 358                       0.434027                      0.290173
# 359                       0.061549                      0.379253
# 360                       0.114929                      0.221618
# 361                       0.253622                      0.235186
#
#      NFC_contra_SomMot_ipsi_Vis  NFC_contra_SomMot_contra_Subcort  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
# ..                          ...                               ...
# 357                    0.423512                          0.166954
# 358                    0.321879                          0.544352
# 359                    0.350227                         -0.055624
# 360                    0.215914                          0.231875
# 361                    0.204784                          0.214460
#
#      NFC_contra_SomMot_ipsi_Subcort
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 357                        0.098820
# 358                        0.491642
# 359                        0.014553
# 360                        0.193647
# 361                        0.196714
#
# [362 rows x 1043 columns]

# %%
# putting lobe into numerical order

# Read the merged TSV file (or the DataFrame you have)
df = combined_df

# Step 1: Filter the DataFrame for rows with dataset = 'LOBE'
lobe_df = df[df['dataset'] == 'LOBE']

# Step 2: Sort the filtered DataFrame by participant_id
lobe_df_sorted = lobe_df.sort_values(by='participant_id')

# Step 3: Combine the sorted DataFrame with the rest of the data
# (keep rows that do not have dataset = 'LOBE')
other_df = df[df['dataset'] != 'LOBE']
final_df = pd.concat([lobe_df_sorted, other_df], ignore_index=True)

# Write the final output TSV file
final_df.to_csv('../resources/merged_tabular_withconn_flipped.tsv', sep='\t', index=False)

# %%
final_df
# Out:
#      participant_id dataset        age sex  age_seizure_onset  \
# 0           sub-006    LOBE   9.000000   M                7.0
# 1           sub-007    LOBE   9.000000   F                7.0
# 2           sub-009    LOBE   8.000000   M                2.0
# 3           sub-010    LOBE  15.000000   M                7.0
# 4           sub-012    LOBE  14.000000   F                4.0
# ..              ...     ...        ...  ..                ...
# 357  sub-HCD2939275     HCP  16.250000   F                NaN
# 358  sub-HCD2945876     HCP  12.000000   M                NaN
# 359  sub-HCD2957277     HCP  17.416667   F                NaN
# 360  sub-HCD2976382     HCP  11.333333   M                NaN
# 361  sub-HCD2990073     HCP  13.583333   F                NaN
#
#      age_ep_diagnosis  ep_duration_first_scan  seizure_duration_first_scan  \
# 0                 8.0                     1.0                          2.0
# 1                 7.0                     2.0                          2.0
# 2                 8.0                     0.0                          6.0
# 3                 7.0                     8.0                          8.0
# 4                10.0                     4.0                         10.0
# ..                ...                     ...                          ...
# 357               NaN                     NaN                          NaN
# 358               NaN                     NaN                          NaN
# 359               NaN                     NaN                          NaN
# 360               NaN                     NaN                          NaN
# 361               NaN                     NaN                          NaN
#
#      pnes  benign_rolandic  ... NFC_contra_Default_ipsi_Default  \
# 0     0.0              0.0  ...                        0.565819
# 1     0.0              0.0  ...                             NaN
# 2     0.0              0.0  ...                             NaN
# 3     0.0              0.0  ...                        0.368043
# 4     0.0              0.0  ...                             NaN
# ..    ...              ...  ...                             ...
# 357   NaN              NaN  ...                             NaN
# 358   NaN              NaN  ...                             NaN
# 359   NaN              NaN  ...                             NaN
# 360   NaN              NaN  ...                             NaN
# 361   NaN              NaN  ...                             NaN
#
#      NFC_contra_DorsAttn_ipsi_DorsAttn  NFC_contra_SomMot_ipsi_SomMot  \
# 0                             0.617860                       0.604727
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                             0.396189                       0.382974
# 4                                  NaN                            NaN
# ..                                 ...                            ...
# 357                                NaN                            NaN
# 358                                NaN                            NaN
# 359                                NaN                            NaN
# 360                                NaN                            NaN
# 361                                NaN                            NaN
#
#      NFC_contra_SomMot_contra_SalVentAttn  NFC_contra_SomMot_contra_Limbic  \
# 0                                0.507667                         0.222434
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                0.308687                         0.143737
# 4                                     NaN                              NaN
# ..                                    ...                              ...
# 357                                   NaN                              NaN
# 358                                   NaN                              NaN
# 359                                   NaN                              NaN
# 360                                   NaN                              NaN
# 361                                   NaN                              NaN
#
#      NFC_contra_SomMot_ipsi_Limbic  NFC_contra_SomMot_contra_Vis  \
# 0                         0.297744                      0.426252
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                         0.065170                      0.373591
# 4                              NaN                           NaN
# ..                             ...                           ...
# 357                            NaN                           NaN
# 358                            NaN                           NaN
# 359                            NaN                           NaN
# 360                            NaN                           NaN
# 361                            NaN                           NaN
#
#      NFC_contra_SomMot_ipsi_Vis  NFC_contra_SomMot_contra_Subcort  \
# 0                      0.418372                          0.510923
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                      0.272360                          0.132701
# 4                           NaN                               NaN
# ..                          ...                               ...
# 357                         NaN                               NaN
# 358                         NaN                               NaN
# 359                         NaN                               NaN
# 360                         NaN                               NaN
# 361                         NaN                               NaN
#
#      NFC_contra_SomMot_ipsi_Subcort
# 0                          0.426699
# 1                               NaN
# 2                               NaN
# 3                          0.018980
# 4                               NaN
# ..                              ...
# 357                             NaN
# 358                             NaN
# 359                             NaN
# 360                             NaN
# 361                             NaN
#
# [362 rows x 1043 columns]

# %% [markdown]
# # Stop here for Flipping #

# %% [markdown]
# ## Brainnetome ##

# %%
import pandas as pd

# Step 1: Load the brainnetome labels file (File 1)
file_path = '../resources/brainnetome/brainnetome_labels_nonet.txt'
df1 = pd.read_csv(file_path, header=None, names=['Label', 'Number', 'R', 'G', 'B', 'Alpha'], sep=" ", comment="#")

# Step 2: Load the network mapping file (File 2)
network_mapping = pd.read_csv('../resources/brainnetome/subregion_func_network_Yeo_updated.csv')

# Step 3: Inspect the columns of the network_mapping dataframe
print(network_mapping.columns)  # Check the column names to ensure correct usage

# Step 4: Clean the 'Number' column in df1 (handle NaN or invalid values)
df1 = df1.dropna(subset=['Number'])  # Drop rows where 'Number' is NaN

# Ensure 'Number' is converted to integers
df1['Number'] = df1['Number'].astype(int)

# Step 5: Merge the dataframes on 'Number' to get the 'Yeo_7network' values
# We need to confirm the exact column name for network in network_mapping
# Let's use 'Yeo_7network' if that's the column that contains the network values
df1 = pd.merge(df1, network_mapping[['Yeo_7network']], how='left', left_on='Number', right_on='Yeo_7network')

# Step 6: Modify the labels
# Now, append the Yeo_7network number to the label for every row starting with "L" or "R"
for index, row in df1.iterrows():
    if row['Label'].startswith(('L', 'R')):  # Check if the label starts with 'L' or 'R'
        # Append the Yeo_7network number to the label
        new_label = f"{row['Label']}_{row['Yeo_7network']}"
        df1.at[index, 'Label'] = new_label

# Step 7: Save the updated DataFrame with new labels back to a new file (or overwrite the original)
df1.to_csv('../resources/brainnetome/updated_brainnetome_labels.txt', index=False, header=False, sep=" ")

# Optional: Check the first few rows to verify
print(df1.head())
# Out:
# Index(['Label', 'subregion_name', 'region', 'Yeo_7network', 'Yeo_17network',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')
#   Label  Number      R    G      B  Alpha  Yeo_7network
# 0     1       0  255.0  0.0  255.0    NaN           0.0
# 1     1       0  255.0  0.0  255.0    NaN           0.0
# 2     1       0  255.0  0.0  255.0    NaN           0.0
# 3     1       0  255.0  0.0  255.0    NaN           0.0
# 4     1       0  255.0  0.0  255.0    NaN           0.0

# %%
import pandas as pd

# Step 1: Load the CSV file containing the data
file_path = '../resources/brainnetome/subregion_func_network_Yeo_updated.csv'
network_mapping = pd.read_csv(file_path)

# Step 2: Inspect the columns of the network_mapping dataframe
print("Columns in network_mapping:", network_mapping.columns)

# Step 3: Create the new names based on the format L_A8m_6 or R_A8m_6
# We'll assume the columns are named 'region', 'subregion_name', and 'Yeo_17network'
# Modify this if the column names are different.

# Step 4: Combine the columns into the desired format
network_mapping['new_name'] = network_mapping['region'] + '_' + network_mapping['subregion_name'] + '_' + network_mapping['Yeo_7network'].astype(str)

# Step 5: Save the new names to a .txt file
output_file_path = '../resources/brainnetome/updated_brainnetome_labels.txt'

# Writing the 'new_name' column to a file, each name on a new line
network_mapping['new_name'].to_csv(output_file_path, index=False, header=False)

print(f"New labels have been written to {output_file_path}")
# Out:
# Columns in network_mapping: Index(['Label', 'subregion_name', 'region', 'Yeo_7network'], dtype='object')
# New labels have been written to ../resources/brainnetome/updated_brainnetome_labels.txt

# %%
import pandas as pd

# Step 1: Load the CSV file containing the data
file_path = '../resources/brainnetome/subregion_func_network_Yeo_updated.csv'
network_mapping = pd.read_csv(file_path)

# Step 2: Combine the columns into the desired format (L_A8m_6, for example)
network_mapping['new_name'] = network_mapping['region'] + '_' + network_mapping['subregion_name'] + '_' + network_mapping['Yeo_7network'].astype(str)

# Step 3: Modify the name according to your specifications
# The names are in the format 'SFG_L_7_1_A8m_6', and we want to get 'L_A8m_6'

def modify_name(name):
    # Split the name by underscores
    parts = name.split('_')
    
    # We're interested in the region (second part), subregion name (last part), and network number (second-to-last part)
    return f"{parts[1]}_{parts[-2]}_{parts[-1]}"  # Take the region (L/R), subregion name, and network number

# Apply the modify_name function to each new_name
network_mapping['modified_name'] = network_mapping['new_name'].apply(modify_name)

# Step 4: Save the modified names to a new .txt file
output_file_path = '../resources/brainnetome/modified_brainnetome_labels.txt'

# Writing the modified names to the file, each name on a new line
network_mapping['modified_name'].to_csv(output_file_path, index=False, header=False)

print(f"Modified labels have been written to {output_file_path}")
# Out:
# Modified labels have been written to ../resources/brainnetome/modified_brainnetome_labels.txt

# %%
# File paths
labels_file_path = '../resources/brainnetome/brainnetome_labels.txt'
modified_labels_file_path = '../resources/brainnetome/modified_brainnetome_labels.txt'
output_file_path = '../resources/brainnetome/brainnetome_labels_net.txt'

# Step 1: Read the modified names from the modified_brainnetome_labels.txt
with open(modified_labels_file_path, 'r') as f:
    modified_names = f.read().splitlines()

# Step 2: Create a dictionary to map the base names (e.g., L_A8m) to modified names (e.g., L_A8m_6)
modified_names_dict = {}
for modified_name in modified_names:
    parts = modified_name.split('_')
    if len(parts) == 3:  # Only process names that have a '_number' format
        base_name = '_'.join(parts[:2])  # Extract base name (e.g., L_A8m)
        modified_names_dict[base_name] = modified_name  # Map base name to the full modified name (e.g., L_A8m_6)

# Debug: Print out the dictionary to confirm it's being created correctly
print("Modified Names Dictionary:", modified_names_dict)

# Step 3: Read the original labels file and modify the names
updated_lines = []
name_line = True  # Flag to indicate whether we are processing a name line or a data line

with open(labels_file_path, 'r') as f:
    original_lines = f.readlines()

# Step 4: Loop through the original lines, replace the names, and build the new lines
for i in range(0, len(original_lines), 2):  # We step by 2, assuming the name is followed by data on the next line
    name_line = original_lines[i].strip()  # Get the name (e.g., L_A8m)
    data_line = original_lines[i+1].strip()  # Get the associated data line (e.g., 1 0 255 0 255)

    # Debug: Print out each line being processed
    print("\nProcessing name line:", repr(name_line))
    print("Processing data line:", repr(data_line))

    # Check if it's a name line (i.e., doesn't contain numeric data)
    parts = name_line.split()  # Split the name line by whitespace

    if len(parts) == 1:  # This means the line is just a name (e.g., L_A8m)
        original_name = parts[0]  # Extract the base name (e.g., L_A8m)
        
        # Check if the original name exists in the dictionary
        if original_name in modified_names_dict:
            new_name = modified_names_dict[original_name]  # e.g., L_A8m_6
            print(f"Replacing {original_name} with {new_name}")
            updated_lines.append(new_name + '\n')  # Append the updated name line, followed by a newline
            updated_lines.append(data_line + '\n')  # Append the original data line with a newline
        else:
            print(f"No replacement found for {original_name}")
            updated_lines.append(name_line + '\n')  # If no modification, append the original name line
            updated_lines.append(data_line + '\n')  # Append the data line without modification
    else:
        # This should not happen in this loop, but we handle it for safety
        updated_lines.append(name_line + '\n')  # If no modification, append the original name line
        updated_lines.append(data_line + '\n')  # Append the data line without modification

# Step 5: Write the updated content to the new file (modified_brainnetome_labels_net.txt)
with open(output_file_path, 'w') as f:
    f.writelines(updated_lines)

print(f"\nUpdated labels have been written to {output_file_path}")
# Out:
# Modified Names Dictionary: {'L_A8m': 'L_A8m_6', 'R_A8m': 'R_A8m_4', 'L_A8dl': 'L_A8dl_7', 'R_A8dl': 'R_A8dl_6', 'L_A9l': 'L_A9l_7', 'R_A9l': 'R_A9l_7', 'L_A6dl': 'L_A6dl_3', 'R_A6dl': 'R_A6dl_3', 'L_A6m': 'L_A6m_2', 'R_A6m': 'R_A6m_2', 'L_A9m': 'L_A9m_7', 'R_A9m': 'R_A9m_6', 'L_A10m': 'L_A10m_7', 'R_A10m': 'R_A10m_7', 'L_A9/46d': 'L_A9/46d_4', 'R_A9/46d': 'R_A9/46d_6', 'L_IFJ': 'L_IFJ_6', 'R_IFJ': 'R_IFJ_6', 'L_A46': 'L_A46_6', 'R_A46': 'R_A46_6', 'L_A9/46v': 'L_A9/46v_6', 'R_A9/46v': 'R_A9/46v_6', 'L_A8vl': 'L_A8vl_7', 'R_A8vl': 'R_A8vl_6', 'L_A6vl': 'L_A6vl_3', 'R_A6vl': 'R_A6vl_3', 'L_A10l': 'L_A10l_5', 'R_A10l': 'R_A10l_6', 'L_A44d': 'L_A44d_6', 'R_A44d': 'R_A44d_3', 'L_IFS': 'L_IFS_6', 'R_IFS': 'R_IFS_6', 'L_A45c': 'L_A45c_7', 'R_A45c': 'R_A45c_7', 'L_A45r': 'L_A45r_7', 'R_A45r': 'R_A45r_6', 'L_A44op': 'L_A44op_4', 'R_A44op': 'R_A44op_4', 'L_A44v': 'L_A44v_4', 'R_A44v': 'R_A44v_4', 'L_A14m': 'L_A14m_7', 'R_A14m': 'R_A14m_7', 'L_A12/47o': 'L_A12/47o_7', 'R_A12/47o': 'R_A12/47o_7', 'L_A11l': 'L_A11l_5', 'R_A11l': 'R_A11l_6', 'L_A11m': 'L_A11m_5', 'R_A11m': 'R_A11m_5', 'L_A13': 'L_A13_5', 'R_A13': 'R_A13_5', 'L_A12/47l': 'L_A12/47l_7', 'R_A12/47l': 'R_A12/47l_7', 'L_A4hf': 'L_A4hf_2', 'R_A4hf': 'R_A4hf_2', 'L_A6cdl': 'L_A6cdl_3', 'R_A6cdl': 'R_A6cdl_3', 'L_A4ul': 'L_A4ul_2', 'R_A4ul': 'R_A4ul_2', 'L_A4t': 'L_A4t_2', 'R_A4t': 'R_A4t_2', 'L_A4tl': 'L_A4tl_4', 'R_A4tl': 'R_A4tl_4', 'L_A6cvl': 'L_A6cvl_3', 'R_A6cvl': 'R_A6cvl_3', 'L_A1/2/3ll': 'L_A1/2/3ll_4', 'R_A1/2/3ll': 'R_A1/2/3ll_2', 'L_A4ll': 'L_A4ll_2', 'R_A4ll': 'R_A4ll_2', 'L_A38m': 'L_A38m_5', 'R_A38m': 'R_A38m_5', 'L_A41/42': 'L_A41/42_2', 'R_A41/42': 'R_A41/42_2', 'L_TE1.0/TE1.2': 'L_TE1.0/TE1.2_2', 'R_TE1.0/TE1.2': 'R_TE1.0/TE1.2_2', 'L_A22c': 'L_A22c_2', 'R_A22c': 'R_A22c_2', 'L_A38l': 'L_A38l_5', 'R_A38l': 'R_A38l_5', 'L_A22r': 'L_A22r_7', 'R_A22r': 'R_A22r_7', 'L_A21c': 'L_A21c_7', 'R_A21c': 'R_A21c_6', 'L_A21r': 'L_A21r_7', 'R_A21r': 'R_A21r_7', 'L_A37dl': 'L_A37dl_3', 'R_A37dl': 'R_A37dl_3', 'L_aSTS': 'L_aSTS_7', 'R_aSTS': 'R_aSTS_7', 'L_A20iv': 'L_A20iv_5', 'R_A20iv': 'R_A20iv_5', 'L_A37elv': 'L_A37elv_3', 'R_A37elv': 'R_A37elv_3', 'L_A20r': 'L_A20r_5', 'R_A20r': 'R_A20r_5', 'L_A20il': 'L_A20il_7', 'R_A20il': 'R_A20il_5', 'L_A37vl': 'L_A37vl_3', 'R_A37vl': 'R_A37vl_3', 'L_A20cl': 'L_A20cl_6', 'R_A20cl': 'R_A20cl_6', 'L_A20cv': 'L_A20cv_5', 'R_A20cv': 'R_A20cv_5', 'L_A20rv': 'L_A20rv_5', 'R_A20rv': 'R_A20rv_5', 'L_A37mv': 'L_A37mv_1', 'R_A37mv': 'R_A37mv_1', 'L_A37lv': 'L_A37lv_3', 'R_A37lv': 'R_A37lv_1', 'L_A35/36r': 'L_A35/36r_5', 'R_A35/36r': 'R_A35/36r_5', 'L_A35/36c': 'L_A35/36c_5', 'R_A35/36c': 'R_A35/36c_1', 'L_TL': 'L_TL_1', 'R_TL': 'R_TL_1', 'L_A28/34': 'L_A28/34_5', 'R_A28/34': 'R_A28/34_5', 'L_TI': 'L_TI_5', 'R_TI': 'R_TI_5', 'L_TH': 'L_TH_1', 'R_TH': 'R_TH_1', 'L_rpSTS': 'L_rpSTS_7', 'R_rpSTS': 'R_rpSTS_7', 'L_cpSTS': 'L_cpSTS_4', 'R_cpSTS': 'R_cpSTS_4', 'L_A7r': 'L_A7r_3', 'R_A7r': 'R_A7r_3', 'L_A7c': 'L_A7c_3', 'R_A7c': 'R_A7c_3', 'L_A5l': 'L_A5l_3', 'R_A5l': 'R_A5l_3', 'L_A7pc': 'L_A7pc_2', 'R_A7pc': 'R_A7pc_2', 'L_A7ip': 'L_A7ip_3', 'R_A7ip': 'R_A7ip_3', 'L_A39c': 'L_A39c_1', 'R_A39c': 'R_A39c_1', 'L_A39rd': 'L_A39rd_6', 'R_A39rd': 'R_A39rd_6', 'L_A40rd': 'L_A40rd_3', 'R_A40rd': 'R_A40rd_3', 'L_A40c': 'L_A40c_7', 'R_A40c': 'R_A40c_6', 'L_A39rv': 'L_A39rv_3', 'R_A39rv': 'R_A39rv_7', 'L_A40rv': 'L_A40rv_2', 'R_A40rv': 'R_A40rv_2', 'L_A7m': 'L_A7m_6', 'R_A7m': 'R_A7m_6', 'L_A5m': 'L_A5m_2', 'R_A5m': 'R_A5m_3', 'L_dmPOS': 'L_dmPOS_1', 'R_dmPOS': 'R_dmPOS_1', 'L_A31': 'L_A31_7', 'R_A31': 'R_A31_7', 'L_A1/2/3ulhf': 'L_A1/2/3ulhf_2', 'R_A1/2/3ulhf': 'R_A1/2/3ulhf_2', 'L_A1/2/3tonIa': 'L_A1/2/3tonIa_2', 'R_A1/2/3tonIa': 'R_A1/2/3tonIa_2', 'L_A2': 'L_A2_3', 'R_A2': 'R_A2_2', 'L_A1/2/3tru': 'L_A1/2/3tru_2', 'R_A1/2/3tru': 'R_A1/2/3tru_2', 'L_G': 'L_G_2', 'R_G': 'R_G_2', 'L_vIa': 'L_vIa_0', 'R_vIa': 'R_vIa_6', 'L_dIa': 'L_dIa_4', 'R_dIa': 'R_dIa_4', 'L_vId/vIg': 'L_vId/vIg_4', 'R_vId/vIg': 'R_vId/vIg_4', 'L_dIg': 'L_dIg_2', 'R_dIg': 'R_dIg_2', 'L_dId': 'L_ ...
#
# Processing name line: 'L_A8m'
# Processing data line: '1 0 255 0 255'
# Replacing L_A8m with L_A8m_6
#
# Processing name line: 'R_A8m'
# Processing data line: '2 0 0 255 255'
# Replacing R_A8m with R_A8m_4
#
# Processing name line: 'L_A8dl'
# Processing data line: '3 255 0 0 255'
# Replacing L_A8dl with L_A8dl_7
#
# Processing name line: 'R_A8dl'
# Processing data line: '4 0 246 255 255'
# Replacing R_A8dl with R_A8dl_6
#
# Processing name line: 'L_A9l'
# Processing data line: '5 255 123 220 255'
# Replacing L_A9l with L_A9l_7
#
# Processing name line: 'R_A9l'
# Processing data line: '6 255 220 123 255'
# Replacing R_A9l with R_A9l_7
#
# Processing name line: 'L_A6dl'
# Processing data line: '7 0 141 255 255'
# Replacing L_A6dl with L_A6dl_3
#
# Processing name line: 'R_A6dl'
# Processing data line: '8 0 106 9 255'
# Replacing R_A6dl with R_A6dl_3
#
# Processing name line: 'L_A6m'
# Processing data line: '9 158 70 53 255'
# Replacing L_A6m with L_A6m_2
#
# Processing name line: 'R_A6m'
# Processing data line: '10 62 0 106 255'
# Replacing R_A6m with R_A6m_2
#
# Processing name line: 'L_A9m'
# Processing data line: '11 255 237 255 255'
# Replacing L_A9m with L_A9m_7
#
# Processing name line: 'R_A9m'
# Processing data line: '12 141 255 158 255'
# Replacing R_A9m with R_A9m_6
#
# Processing name line: 'L_A10m'
# Processing data line: '13 229 0 255 255'
# Replacing L_A10m with L_A10m_7
#
# Processing name line: 'R_A10m'
# Processing data line: '14 79 123 141 255'
# Replacing R_A10m with R_A10m_7
#
# Processing name line: 'L_A9/46d'
# Processing data line: '15 220 255 0 255'
# Replacing L_A9/46d with L_A9/46d_4
#
# Processing name line: 'R_A9/46d'
# Processing data line: '16 255 0 106 255'
# Replacing R_A9/46d with R_A9/46d_6
#
# Processing name line: 'L_IFJ'
# Processing data line: '17 237 132 0 255'
# Replacing L_IFJ with L_IFJ_6
#
# Processing name line: 'R_IFJ'
# Processing data line: '18 123 88 246 255'
# Replacing R_IFJ with R_IFJ_6
#
# Processing name line: 'L_A46'
# Processing data line: '19 141 0 88 255'
# Replacing L_A46 with L_A46_6
#
# Processing name line: 'R_A46'
# Processing data line: '20 123 106 0 255'
# Replacing R_A46 with R_A46_6
#
# Processing name line: 'L_A9/46v'
# Processing data line: '21 158 185 141 255'
# Replacing L_A9/46v with L_A9/46v_6
#
# Processing name line: 'R_A9/46v'
# Processing data line: '22 141 106 176 255'
# Replacing R_A9/46v with R_A9/46v_6
#
# Processing name line: 'L_A8vl'
# Processing data line: '23 97 185 0 255'
# Replacing L_A8vl with L_A8vl_7
#
# Processing name line: 'R_A8vl'
# Processing data line: '24 255 158 176 255'
# Replacing R_A8vl with R_A8vl_6
#
# Processing name line: 'L_A6vl'
# Processing data line: '25 0 44 97 255'
# Replacing L_A6vl with L_A6vl_3
#
# Processing name line: 'R_A6vl'
# Processing data line: '26 62 193 255 255'
# Replacing R_A6vl with R_A6vl_3
#
# Processing name line: 'L_A10l'
# Processing data line: '27 62 79 44 255'
# Replacing L_A10l with L_A10l_5
#
# Processing name line: 'R_A10l'
# Processing data line: '28 167 9 167 255'
# Replacing R_A10l with R_A10l_6
#
# Processing name line: 'L_A44d'
# Processing data line: '29 97 62 79 255'
# Replacing L_A44d with L_A44d_6
#
# Processing name line: 'R_A44d'
# Processing data line: '30 0 185 141 255'
# Replacing R_A44d with R_A44d_3
#
# Processing name line: 'L_IFS'
# Processing data line: '31 255 211 0 255'
# Replacing L_IFS with L_IFS_6
#
# Processing name line: 'R_IFS'
# Processing data line: '32 255 106 79 255'
# Replacing R_IFS with R_IFS_6
#
# Processing name line: 'L_A45c'
# Processing data line: '33 0 0 158 255'
# Replacing L_A45c with L_A45c_7
#
# Processing name line: 'R_A45c'
# Processing data line: '34 70 0 0 255'
# Replacing R_A45c with R_A45c_7
#
# Processing name line: 'L_A45r'
# Processing data line: '35 237 185 255 255'
# Replacing L_A45r with L_A45r_7
#
# Processing name line: 'R_A45r'
# Processing data line: '36 202 149 106 255'
# Replacing R_A45r with R_A45r_6
#
# Processing name line: 'L_A44op'
# Processing data line: '37 255 0 167 255'
# Replacing L_A44op with L_A44op_4
#
# Processing name line: 'R_A44op'
# Processing data line: '38 220 255 123 255'
# Replacing R_A44op with R_A44op_4
#
# Processing name line: 'L_A44v'
# Processing data line: '39 44 70 176 255'
# Replacing L_A44v with L_A44v_4
#
# Processing name line: 'R_A44v'
# Processing data line: '40 158 167 0 255'
# Replacing R_A44v with R_A44v_4
#
# Processing name line: 'L_A14m'
# Processing data line: '41 149 211 220 255'
# Replacing L_A14m with L_A14m_7
#
# Processing name line: 'R_A14m'
# Processing data line: '42 176 149 167 255'
# Replacing R_A14m with R_A14m_7
#
# Processing name line: 'L_A12/47o'
# Processing data line: '43 202 132 255 255'
# Replacing L_A12/47o with L_A12/47o_7
#
# Processing name line: 'R_A12/47o'
# Processing data line: '44 0 255 114 255'
# Replacing R_A12/47o with R_A12/47o_7
#
# Processing name line: 'L_A11l'
# Processing data line: '45 167 0 0 255'
# Replacing L_A11l with L_A11l_5
#
# Processing name line: 'R_A11l'
# Processing data line: '46 132 0 229 255'
# Replacing R_A11l with R_A11l_6
#
# Processing name line: 'L_A11m'
# Processing data line: '47 44 0 44 255'
# Replacing L_A11m with L_A11m_5
#
# Processing name line: 'R_A11m'
# Processing data line: '48 255 255 202 255'
# Replacing R_A11m with R_A11m_5
#
# Processing name line: 'L_A13'
# Processing data line: '49 229 79 141 255'
# Replacing L_A13 with L_A13_5
#
# Processing name line: 'R_A13'
# Processing data line: '50 176 255 211 255'
# Replacing R_A13 with R_A13_5
#
# Processing name line: 'L_A12/47l'
# Processing data line: '51 0 176 79 255'
# Replacing L_A12/47l with L_A12/47l_7
#
# Processing name line: 'R_A12/47l'
# Processing data line: '52 88 53 0 255'
# Replacing R_A12/47l with R_A12/47l_7
#
# Processing name line: 'L_A4hf'
# Processing data line: '53 0 106 167 255'
# Replacing L_A4hf with L_A4hf_2
#
# Processing name line: 'R_A4hf'
# Processing data line: '54 149 167 229 255'
# Replacing R_A4hf with R_A4hf_2
#
# Processing name line: 'L_A6cdl'
# Processing data line: '55 141 193 97 255'
# Replacing L_A6cdl with L_A6cdl_3
#
# Processing name line: 'R_A6cdl'
# Processing data line: '56 35 123 97 255'
# Replacing R_A6cdl with R_A6cdl_3
#
# Processing name line: 'L_A4ul'
# Processing data line: '57 176 97 132 255'
# Replacing L_A4ul with L_A4ul_2
#
# Processing name line: 'R_A4ul'
# Processing data line: '58 176 0 62 255'
# Replacing R_A4ul with R_A4ul_2
#
# Processing name line: 'L_A4t'
# Processing data line: '59 167 88 0 255'
# Replacing L_A4t with L_A4t_2
#
# Processing name line: 'R_A4t'
# Processing data line: '60 255 62 229 255'
# Replacing R_A4t with R_A4t_2
#
# Processing name line: 'L_A4tl'
# Processing data line: '61 0 62 70 255'
# Replacing L_A4tl with L_A4tl_4
#
# Processing name line: 'R_A4tl'
# Processing data line: '62 149 255 62 255'
# Replacing R_A4tl with R_A4tl_4
#
# Processing name line: 'L_A6cvl'
# Processing data line: '63 132 106 88 255'
# Replacing L_A6cvl with L_A6cvl_3
#
# Processing name line: 'R_A6cvl'
# Processing data line: '64 0 255 202 255'
# Replacing R_A6cvl with R_A6cvl_3
#
# Processing name line: 'L_A1/2/3ll'
# Processing data line: '65 202 149 44 255'
# Replacing L_A1/2/3ll with L_A1/2/3ll_4
#
# Processing name line: 'R_A1/2/3ll'
# Processing data line: '66 255 0 62 255'
# Replacing R_A1/2/3ll with R_A1/2/3ll_2
#
# Processing name line: 'L_A4ll'
# Processing data line: '67 106 132 62 255'
# Replacing L_A4ll with L_A4ll_2
#
# Processing name line: 'R_A4ll'
# Processing data line: '68 0 62 255 255'
# Replacing R_A4ll with R_A4ll_2
#
# Processing name line: 'L_A38m'
# Processing data line: '69 0 167 176 255'
# Replacing L_A38m with L_A38m_5
#
# Processing name line: 'R_A38m'
# Processing data line: '70 202 88 255 255'
# Replacing R_A38m with R_A38m_5
#
# Processing name line: 'L_A41/42'
# Processing data line: '71 255 202 185 255'
# Replacing L_A41/42 with L_A41/42_2
#
# Processing name line: 'R_A41/42'
# Processing data line: '72 106 44 106 255'
# Replacing R_A41/42 with R_A41/42_2
#
# Processing name line: 'L_TE1.0/TE1.2'
# Processing data line: '73 255 158 97 255'
# Replacing L_TE1.0/TE1.2 with L_TE1.0/TE1.2_2
#
# Processing name line: 'R_TE1.0/TE1.2'
# Processing data line: '74 132 70 185 255'
# Replacing R_TE1.0/TE1.2 with R_TE1.0/TE1.2_2
#
# Processing name line: 'L_A22c'
# Processing data line: '75 176 70 158 255'
# Replacing L_A22c with L_A22c_2
#
# Processing name line: 'R_A22c'
# Processing data line: '76 149 149 255 255'
# Replacing R_A22c with R_A22c_2
#
# Processing name line: 'L_A38l'
# Processing data line: '77 255 106 123 255'
# Replacing L_A38l with L_A38l_5
#
# Processing name line: 'R_A38l'
# Processing data line: '78 0 106 255 255'
# Replacing R_A38l with R_A38l_5
#
# Processing name line: 'L_A22r'
# Processing data line: '79 114 9 176 255'
# Replacing L_A22r with L_A22r_7
#
# Processing name line: 'R_A22r'
# Processing data line: '80 176 167 79 255'
# Replacing R_A22r with R_A22r_7
#
# Processing name line: 'L_A21c'
# Processing data line: '81 229 79 0 255'
# Replacing L_A21c with L_A21c_7
#
# Processing name line: 'R_A21c'
# Processing data line: '82 0 0 70 255'
# Replacing R_A21c with R_A21c_6
#
# Processing name line: 'L_A21r'
# Processing data line: '83 53 35 18 255'
# Replacing L_A21r with L_A21r_7
#
# Processing name line: 'R_A21r'
# Processing data line: '84 88 141 0 255'
# Replacing R_A21r with R_A21r_7
#
# Processing name line: 'L_A37dl'
# Processing data line: '85 0 35 9 255'
# Replacing L_A37dl with L_A37dl_3
#
# Processing name line: 'R_A37dl'
# Processing data line: '86 26 211 18 255'
# Replacing R_A37dl with R_A37dl_3
#
# Processing name line: 'L_aSTS'
# Processing data line: '87 123 44 62 255'
# Replacing L_aSTS with L_aSTS_7
#
# Processing name line: 'R_aSTS'
# Processing data line: '88 88 88 132 255'
# Replacing R_aSTS with R_aSTS_7
#
# Processing name line: 'L_A20iv'
# Processing data line: '89 237 237 70 255'
# Replacing L_A20iv with L_A20iv_5
#
# Processing name line: 'R_A20iv'
# Processing data line: '90 0 62 0 255'
# Replacing R_A20iv with R_A20iv_5
#
# Processing name line: 'L_A37elv'
# Processing data line: '91 211 229 211 255'
# Replacing L_A37elv with L_A37elv_3
#
# Processing name line: 'R_A37elv'
# Processing data line: '92 114 0 0 255'
# Replacing R_A37elv with R_A37elv_3
#
# Processing name line: 'L_A20r'
# Processing data line: '93 202 246 167 255'
# Replacing L_A20r with L_A20r_5
#
# Processing name line: 'R_A20r'
# Processing data line: '94 167 211 9 255'
# Replacing R_A20r with R_A20r_5
#
# Processing name line: 'L_A20il'
# Processing data line: '95 246 141 123 255'
# Replacing L_A20il with L_A20il_7
#
# Processing name line: 'R_A20il'
# Processing data line: '96 26 141 79 255'
# Replacing R_A20il with R_A20il_5
#
# Processing name line: 'L_A37vl'
# Processing data line: '97 114 141 123 255'
# Replacing L_A37vl with L_A37vl_3
#
# Processing name line: 'R_A37vl'
# Processing data line: '98 193 0 132 255'
# Replacing R_A37vl with R_A37vl_3
#
# Processing name line: 'L_A20cl'
# Processing data line: '99 0 18 44 255'
# Replacing L_A20cl with L_A20cl_6
#
# Processing name line: 'R_A20cl'
# Processing data line: '100 106 220 202 255'
# Replacing R_A20cl with R_A20cl_6
#
# Processing name line: 'L_A20cv'
# Processing data line: '101 70 79 0 255'
# Replacing L_A20cv with L_A20cv_5
#
# Processing name line: 'R_A20cv'
# Processing data line: '102 149 97 44 255'
# Replacing R_A20cv with R_A20cv_5
#
# Processing name line: 'L_A20rv'
# Processing data line: '103 185 114 106 255'
# Replacing L_A20rv with L_A20rv_5
#
# Processing name line: 'R_A20rv'
# Processing data line: '104 0 26 141 255'
# Replacing R_A20rv with R_A20rv_5
#
# Processing name line: 'L_A37mv'
# Processing data line: '105 0 255 158 255'
# Replacing L_A37mv with L_A37mv_1
#
# Processing name line: 'R_A37mv'
# Processing data line: '106 255 176 9 255'
# Replacing R_A37mv with R_A37mv_1
#
# Processing name line: 'L_A37lv'
# Processing data line: '107 123 202 141 255'
# Replacing L_A37lv with L_A37lv_3
#
# Processing name line: 'R_A37lv'
# Processing data line: '108 123 237 97 255'
# Replacing R_A37lv with R_A37lv_1
#
# Processing name line: 'L_A35/36r'
# Processing data line: '109 79 88 88 255'
# Replacing L_A35/36r with L_A35/36r_5
#
# Processing name line: 'R_A35/36r'
# Processing data line: '110 220 132 193 255'
# Replacing R_A35/36r with R_A35/36r_5
#
# Processing name line: 'L_A35/36c'
# Processing data line: '111 114 0 114 255'
# Replacing L_A35/36c with L_A35/36c_5
#
# Processing name line: 'R_A35/36c'
# Processing data line: '112 211 193 141 255'
# Replacing R_A35/36c with R_A35/36c_1
#
# Processing name line: 'L_TL'
# Processing data line: '113 185 193 220 255'
# Replacing L_TL with L_TL_1
#
# Processing name line: 'R_TL'
# Processing data line: '114 79 97 176 255'
# Replacing R_TL with R_TL_1
#
# Processing name line: 'L_A28/34'
# Processing data line: '115 88 0 53 255'
# Replacing L_A28/34 with L_A28/34_5
#
# Processing name line: 'R_A28/34'
# Processing data line: '116 193 79 97 255'
# Replacing R_A28/34 with R_A28/34_5
#
# Processing name line: 'L_TI'
# Processing data line: '117 70 53 123 255'
# Replacing L_TI with L_TI_5
#
# Processing name line: 'R_TI'
# Processing data line: '118 220 193 53 255'
# Replacing R_TI with R_TI_5
#
# Processing name line: 'L_TH'
# Processing data line: '119 185 167 149 255'
# Replacing L_TH with L_TH_1
#
# Processing name line: 'R_TH'
# Processing data line: '120 220 97 229 255'
# Replacing R_TH with R_TH_1
#
# Processing name line: 'L_rpSTS'
# Processing data line: '121 141 123 70 255'
# Replacing L_rpSTS with L_rpSTS_7
#
# Processing name line: 'R_rpSTS'
# Processing data line: '122 0 141 185 255'
# Replacing R_rpSTS with R_rpSTS_7
#
# Processing name line: 'L_cpSTS'
# Processing data line: '123 9 62 211 255'
# Replacing L_cpSTS with L_cpSTS_4
#
# Processing name line: 'R_cpSTS'
# Processing data line: '124 114 106 229 255'
# Replacing R_cpSTS with R_cpSTS_4
#
# Processing name line: 'L_A7r'
# Processing data line: '125 255 193 229 255'
# Replacing L_A7r with L_A7r_3
#
# Processing name line: 'R_A7r'
# Processing data line: '126 70 149 229 255'
# Replacing R_A7r with R_A7r_3
#
# Processing name line: 'L_A7c'
# Processing data line: '127 0 149 0 255'
# Replacing L_A7c with L_A7c_3
#
# Processing name line: 'R_A7c'
# Processing data line: '128 44 9 18 255'
# Replacing R_A7c with R_A7c_3
#
# Processing name line: 'L_A5l'
# Processing data line: '129 193 79 44 255'
# Replacing L_A5l with L_A5l_3
#
# Processing name line: 'R_A5l'
# Processing data line: '130 255 193 132 255'
# Replacing R_A5l with R_A5l_3
#
# Processing name line: 'L_A7pc'
# Processing data line: '131 44 44 53 255'
# Replacing L_A7pc with L_A7pc_2
#
# Processing name line: 'R_A7pc'
# Processing data line: '132 53 220 255 255'
# Replacing R_A7pc with R_A7pc_2
#
# Processing name line: 'L_A7ip'
# Processing data line: '133 211 53 62 255'
# Replacing L_A7ip with L_A7ip_3
#
# Processing name line: 'R_A7ip'
# Processing data line: '134 141 106 141 255'
# Replacing R_A7ip with R_A7ip_3
#
# Processing name line: 'L_A39c'
# Processing data line: '135 106 176 149 255'
# Replacing L_A39c with L_A39c_1
#
# Processing name line: 'R_A39c'
# Processing data line: '136 35 0 202 255'
# Replacing R_A39c with R_A39c_1
#
# Processing name line: 'L_A39rd'
# Processing data line: '137 211 220 123 255'
# Replacing L_A39rd with L_A39rd_6
#
# Processing name line: 'R_A39rd'
# Processing data line: '138 123 53 0 255'
# Replacing R_A39rd with R_A39rd_6
#
# Processing name line: 'L_A40rd'
# Processing data line: '139 167 0 211 255'
# Replacing L_A40rd with L_A40rd_3
#
# Processing name line: 'R_A40rd'
# Processing data line: '140 18 79 114 255'
# Replacing R_A40rd with R_A40rd_3
#
# Processing name line: 'L_A40c'
# Processing data line: '141 9 79 62 255'
# Replacing L_A40c with L_A40c_7
#
# Processing name line: 'R_A40c'
# Processing data line: '142 246 158 255 255'
# Replacing R_A40c with R_A40c_6
#
# Processing name line: 'L_A39rv'
# Processing data line: '143 114 176 211 255'
# Replacing L_A39rv with L_A39rv_3
#
# Processing name line: 'R_A39rv'
# Processing data line: '144 106 62 53 255'
# Replacing R_A39rv with R_A39rv_7
#
# Processing name line: 'L_A40rv'
# Processing data line: '145 53 106 53 255'
# Replacing L_A40rv with L_A40rv_2
#
# Processing name line: 'R_A40rv'
# Processing data line: '146 220 62 185 255'
# Replacing R_A40rv with R_A40rv_2
#
# Processing name line: 'L_A7m'
# Processing data line: '147 0 202 70 255'
# Replacing L_A7m with L_A7m_6
#
# Processing name line: 'R_A7m'
# Processing data line: '148 62 44 79 255'
# Replacing R_A7m with R_A7m_6
#
# Processing name line: 'L_A5m'
# Processing data line: '149 246 9 132 255'
# Replacing L_A5m with L_A5m_2
#
# Processing name line: 'R_A5m'
# Processing data line: '150 185 149 202 255'
# Replacing R_A5m with R_A5m_3
#
# Processing name line: 'L_dmPOS'
# Processing data line: '151 220 18 18 255'
# Replacing L_dmPOS with L_dmPOS_1
#
# Processing name line: 'R_dmPOS'
# Processing data line: '152 176 255 246 255'
# Replacing R_dmPOS with R_dmPOS_1
#
# Processing name line: 'L_A31'
# Processing data line: '153 62 220 149 255'
# Replacing L_A31 with L_A31_7
#
# Processing name line: 'R_A31'
# Processing data line: '154 167 202 70 255'
# Replacing R_A31 with R_A31_7
#
# Processing name line: 'L_A1/2/3ulhf'
# Processing data line: '155 132 141 176 255'
# Replacing L_A1/2/3ulhf with L_A1/2/3ulhf_2
#
# Processing name line: 'R_A1/2/3ulhf'
# Processing data line: '156 88 53 185 255'
# Replacing R_A1/2/3ulhf with R_A1/2/3ulhf_2
#
# Processing name line: 'L_A1/2/3tonIa'
# Processing data line: '157 193 149 237 255'
# Replacing L_A1/2/3tonIa with L_A1/2/3tonIa_2
#
# Processing name line: 'R_A1/2/3tonIa'
# Processing data line: '158 97 114 0 255'
# Replacing R_A1/2/3tonIa with R_A1/2/3tonIa_2
#
# Processing name line: 'L_A2'
# Processing data line: '159 255 132 185 255'
# Replacing L_A2 with L_A2_3
#
# Processing name line: 'R_A2'
# Processing data line: '160 185 0 97 255'
# Replacing R_A2 with R_A2_2
#
# Processing name line: 'L_A1/2/3tru'
# Processing data line: '161 167 237 123 255'
# Replacing L_A1/2/3tru with L_A1/2/3tru_2
#
# Processing name line: 'R_A1/2/3tru'
# Processing data line: '162 255 246 0 255'
# Replacing R_A1/2/3tru with R_A1/2/3tru_2
#
# Processing name line: 'L_G'
# Processing data line: '163 255 193 79 255'
# Replacing L_G with L_G_2
#
# Processing name line: 'R_G'
# Processing data line: '164 220 106 35 255'
# Replacing R_G with R_G_2
#
# Processing name line: 'L_vIa'
# Processing data line: '165 123 0 35 255'
# Replacing L_vIa with L_vIa_0
#
# Processing name line: 'R_vIa'
# Processing data line: '166 193 255 88 255'
# Replacing R_vIa with R_vIa_6
#
# Processing name line: 'L_dIa'
# Processing data line: '167 158 185 176 255'
# Replacing L_dIa with L_dIa_4
#
# Processing name line: 'R_dIa'
# Processing data line: '168 185 70 132 255'
# Replacing R_dIa with R_dIa_4
#
# Processing name line: 'L_vId/vIg'
# Processing data line: '169 202 123 70 255'
# Replacing L_vId/vIg with L_vId/vIg_4
#
# Processing name line: 'R_vId/vIg'
# Processing data line: '170 176 106 202 255'
# Replacing R_vId/vIg with R_vId/vIg_4
#
# Processing name line: 'L_dIg'
# Processing data line: '171 79 149 62 255'
# Replacing L_dIg with L_dIg_2
#
# Processing name line: 'R_dIg'
# Processing data line: '172 0 62 141 255'
# Replacing R_dIg with R_dIg_2
#
# Processing name line: 'L_dId'
# Processing data line: '173 88 44 211 255'
# Replacing L_dId with L_dId_4
#
# Processing name line: 'R_dId'
# Processing data line: '174 246 79 176 255'
# Replacing R_dId with R_dId_4
#
# Processing name line: 'L_A23d'
# Processing data line: '175 158 141 9 255'
# Replacing L_A23d with L_A23d_7
#
# Processing name line: 'R_A23d'
# Processing data line: '176 123 123 132 255'
# Replacing R_A23d with R_A23d_7
#
# Processing name line: 'L_A24rv'
# Processing data line: '177 132 53 97 255'
# Replacing L_A24rv with L_A24rv_0
#
# Processing name line: 'R_A24rv'
# Processing data line: '178 106 158 106 255'
# Replacing R_A24rv with R_A24rv_0
#
# Processing name line: 'L_A32p'
# Processing data line: '179 149 97 106 255'
# Replacing L_A32p with L_A32p_7
#
# Processing name line: 'R_A32p'
# Processing data line: '180 106 202 88 255'
# Replacing R_A32p with R_A32p_4
#
# Processing name line: 'L_A23v'
# Processing data line: '181 211 158 158 255'
# Replacing L_A23v with L_A23v_7
#
# Processing name line: 'R_A23v'
# Processing data line: '182 158 88 149 255'
# Replacing R_A23v with R_A23v_1
#
# Processing name line: 'L_A24cd'
# Processing data line: '183 26 35 123 255'
# Replacing L_A24cd with L_A24cd_4
#
# Processing name line: 'R_A24cd'
# Processing data line: '184 62 9 79 255'
# Replacing R_A24cd with R_A24cd_4
#
# Processing name line: 'L_A23c'
# Processing data line: '185 220 193 202 255'
# Replacing L_A23c with L_A23c_4
#
# Processing name line: 'R_A23c'
# Processing data line: '186 149 62 237 255'
# Replacing R_A23c with R_A23c_4
#
# Processing name line: 'L_A32sg'
# Processing data line: '187 167 97 237 255'
# Replacing L_A32sg with L_A32sg_7
#
# Processing name line: 'R_A32sg'
# Processing data line: '188 97 79 44 255'
# Replacing R_A32sg with R_A32sg_7
#
# Processing name line: 'L_cLinG'
# Processing data line: '189 0 106 106 255'
# Replacing L_cLinG with L_cLinG_1
#
# Processing name line: 'R_cLinG'
# Processing data line: '190 255 246 123 255'
# Replacing R_cLinG with R_cLinG_1
#
# Processing name line: 'L_rCunG'
# Processing data line: '191 88 255 229 255'
# Replacing L_rCunG with L_rCunG_1
#
# Processing name line: 'R_rCunG'
# Processing data line: '192 211 237 255 255'
# Replacing R_rCunG with R_rCunG_1
#
# Processing name line: 'L_cCunG'
# Processing data line: '193 97 35 255 255'
# Replacing L_cCunG with L_cCunG_1
#
# Processing name line: 'R_cCunG'
# Processing data line: '194 106 9 141 255'
# Replacing R_cCunG with R_cCunG_1
#
# Processing name line: 'L_rLinG'
# Processing data line: '195 132 62 149 255'
# Replacing L_rLinG with L_rLinG_1
#
# Processing name line: 'R_rLinG'
# Processing data line: '196 106 114 79 255'
# Replacing R_rLinG with R_rLinG_1
#
# Processing name line: 'L_vmPOS'
# Processing data line: '197 132 255 193 255'
# Replacing L_vmPOS with L_vmPOS_1
#
# Processing name line: 'R_vmPOS'
# Processing data line: '198 158 0 132 255'
# Replacing R_vmPOS with R_vmPOS_1
#
# Processing name line: 'L_mOccG'
# Processing data line: '199 97 158 158 255'
# Replacing L_mOccG with L_mOccG_1
#
# Processing name line: 'R_mOccG'
# Processing data line: '200 202 0 202 255'
# Replacing R_mOccG with R_mOccG_1
#
# Processing name line: 'L_V5/MT+'
# Processing data line: '201 35 106 220 255'
# Replacing L_V5/MT+ with L_V5/MT+_3
#
# Processing name line: 'R_V5/MT+'
# Processing data line: '202 35 44 0 255'
# Replacing R_V5/MT+ with R_V5/MT+_1
#
# Processing name line: 'L_OPC'
# Processing data line: '203 220 97 88 255'
# Replacing L_OPC with L_OPC_1
#
# Processing name line: 'R_OPC'
# Processing data line: '204 114 123 185 255'
# Replacing R_OPC with R_OPC_1
#
# Processing name line: 'L_iOccG'
# Processing data line: '205 149 18 70 255'
# Replacing L_iOccG with L_iOccG_1
#
# Processing name line: 'R_iOccG'
# Processing data line: '206 211 202 255 255'
# Replacing R_iOccG with R_iOccG_1
#
# Processing name line: 'L_msOccG'
# Processing data line: '207 185 0 255 255'
# Replacing L_msOccG with L_msOccG_1
#
# Processing name line: 'R_msOccG'
# Processing data line: '208 0 158 141 255'
# Replacing R_msOccG with R_msOccG_1
#
# Processing name line: 'L_lsOccG'
# Processing data line: '209 211 149 185 255'
# Replacing L_lsOccG with L_lsOccG_1
#
# Processing name line: 'R_lsOccG'
# Processing data line: '210 44 88 0 255'
# Replacing R_lsOccG with R_lsOccG_1
#
# Updated labels have been written to ../resources/brainnetome/modified_brainnetome_labels_net.txt

# %% [markdown]
# # Updating names from numbered net to name of net #

# %%
# Define the number to network mapping
network_mapping = {
    1: 'Vis',
    2: 'SomMot',
    3: 'DorsAttn',
    4: 'SalVentAttn',
    5: 'Limbic',
    6: 'Cont',
    7: 'Default'
}

# Input and output file paths
input_file_path = '../resources/brainnetome/brainnetome_labels_numbernet.txt'
output_file_path = '../resources/brainnetome/brainnetome_labels.txt'

# Step 1: Read the content from the input file
with open(input_file_path, 'r') as f:
    lines = f.readlines()

# Step 2: Process each line
updated_lines = []
for i in range(0, len(lines), 2):  # Iterate by 2 (name, then data)
    name_line = lines[i].strip()  # Name (e.g., L_A8m_6)
    data_line = lines[i + 1].strip()  # Associated data (e.g., 1 0 255 0 255)
    
    # Step 3: Extract the number from the name
    parts = name_line.split('_')
    if len(parts) == 3:  # Expected format is <region>_<subregion>_<number>
        number = int(parts[2])  # The last part is the number (e.g., 6 from L_A8m_6)
        
        # Step 4: Replace the number with the corresponding network name
        if number in network_mapping:
            network_name = network_mapping[number]
            new_name = f"{parts[0]}_{parts[1]}_{network_name}"  # Create the new name
            updated_lines.append(new_name + '\n')  # Add the modified name
            updated_lines.append(data_line + '\n')  # Add the original data line
        else:
            # If the number doesn't exist in the mapping, keep the original name
            updated_lines.append(name_line + '\n')
            updated_lines.append(data_line + '\n')
    else:
        # In case the line format is unexpected, just add the original name and data
        updated_lines.append(name_line + '\n')
        updated_lines.append(data_line + '\n')

# Step 5: Write the updated lines to the output file
with open(output_file_path, 'w') as f:
    f.writelines(updated_lines)

print(f"Updated labels have been written to {output_file_path}")
# Out:
# Updated labels have been written to ../resources/brainnetome/brainnetome_labels.txt

# %% [markdown]
# ## Adding network names to labels txt ##

# %%
# Open the file and read lines
file_path = "../resources/brainnetome/brainnetome_labels.txt"

with open(file_path, "r") as f:
    lines = f.readlines()

# Initialize an empty list to store the names
name_list = []

# Loop through odd lines (indexing starts from 0, so odd lines are at indices 0, 2, 4, etc.)
for i in range(0, len(lines), 2):  # step 2 to select odd lines (0-indexed)
    name = lines[i].split()[0]  # The name is the first part of the line
    name_after_underscore = name.split('_')[2]  # Extract the part after the underscore
    name_list.append(name_after_underscore)

# Define the output file path
output_file_path = "../resources/brainnetome/extracted_net_names.txt"

# Open the output file and write the names to it
with open(output_file_path, "w") as out_file:
    for name in name_list:
        out_file.write(name + "\n")  # Write each name on a new line

print(f"Names have been saved to {output_file_path}")
# Out:
# Names have been saved to ../resources/brainnetome/extracted_net_names.txt

# %% [markdown]
# ## Manually updated extracted_net_names to have new mapping, now need to updated brainnetome_labels.txt to have new mapping in name

# %%
# Step 1: Read the network names from the 'extracted_net_names.txt' file
with open('../resources/brainnetome/extracted_net_names.txt', 'r') as f:
    network_names = [line.strip() for line in f.readlines()]

# Step 2: Read the 'brainnetome_labels.txt' file and store its lines
with open('../resources/brainnetome/brainnetome_labels.txt', 'r') as f:
    lines = f.readlines()

# Step 3: Prepare to replace network names in the labels
updated_lines = []
for i in range(0, len(lines), 2):  # Iterate over the lines in steps of 2 (name + data)
    name = lines[i].strip()  # Get the label name (e.g., L_A8m_Cont)
    data = lines[i+1]  # The corresponding data line
    
    # Replace the last part of the name with the appropriate network name
    # Get the current suffix (e.g., Cont, SalVentAttn) and replace it with the network name
    current_network = name.split('_')[-1]  # The last part (Cont, SalVentAttn, etc.)
    
    # Get the new network name from 'extracted_net_names.txt'
    network_name = network_names[i//2]  # Use integer division to map to the correct network name
    
    # Replace the old network suffix with the new one
    new_name = "_".join(name.split('_')[:-1]) + f"_{network_name}"  # Form the new name
    
    # Append the updated name and its data to the result
    updated_lines.append(new_name + '\n')
    updated_lines.append(data)  # The data stays the same

# Step 4: Write the updated lines to a new file or overwrite the original
with open('../resources/brainnetome/brainnetome_labels.txt', 'w') as f:
    f.writelines(updated_lines)

print("File has been updated and saved as '../resources/brainnetome/brainnetome_labels.txt'.")
# Out:
# File has been updated and saved as '../resources/brainnetome/brainnetome_labels.txt'.

# %%
resources/brainnetome/cort_subcort_labellist.txt
